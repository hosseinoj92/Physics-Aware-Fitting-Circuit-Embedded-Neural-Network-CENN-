# %% [markdown]
# # Cutting data ftom 1 kHz to 5 kHz - Fit - Interpolation

# %%
"""
Batch EIS semicircle fitter — Jupyter/Notebook version
=====================================================

This notebook-friendly script traverses a nested directory structure and fits
a simple complex impedance model (Rs + Zarc/Cole–Cole) to the 1–5 kHz portion
of each impedance spectrum. It writes:
  • a summary CSV with model values at fixed frequencies (1–5 kHz, step 500 Hz)
  • a Nyquist plot PNG of the data and the fitted curve

HOW TO USE IN A NOTEBOOK
------------------------
1) Set ROOT_DIR below to your top-level folder (e.g., 'NPG-500mM-H2SO4-C,T').
2) Run this cell. If ROOT_DIR exists, it will process eligible CSVs right away.
   - Only files whose *basename* ends with '_2' (before '.csv') are processed.

Folder layout expected (example):
    root_dir/
      ├── 1mM/
      │   ├── 26C/
      │   │    ├── <csv files...>
      │   │    └── ...
      │   ├── 28C/
      │   └── ...
      ├── 2mM/
      └── ...

Column naming assumptions:
  • Frequency column contains "frequency" (e.g., "Frequency (Hz)").
  • Real part (Z′) column contains "WE.Z'" or "Z'".
  • Imag part is stored as NEGATIVE imaginary (−Z″), column contains "-Z\"" or "imag".
If your exports differ, adjust `identify_columns`.

Outputs per input file:
  <basename>_1000-5000_fit.csv
  <basename>_1000-5000_fit.png
"""

# --- SET YOUR ROOT FOLDER HERE ---
ROOT_DIR = r'/Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-C,T'  # <- put your root folder here

# --- Imports ---
import os
from typing import Tuple, Sequence, Optional, Dict, List

import numpy as np
import pandas as pd
from scipy.optimize import least_squares
import matplotlib.pyplot as plt


def identify_columns(df: pd.DataFrame) -> Tuple[str, str, str]:
    """Identify the frequency, real and (negative) imaginary column names.

    Heuristics:
      • Frequency: header contains 'frequency'
      • Real part (Z′): header contains "we.z'" or "z'" and NOT a minus sign
      • Negative imag (−Z″): header contains '-z' and either 'imag' or a double quote

    Returns
    -------
    freq_col : str
    zreal_col : str
    zimag_col : str  (NOTE: this is the NEGATIVE imaginary column, i.e., −Z″)
    """
    freq_col: Optional[str] = None
    zreal_col: Optional[str] = None
    zimag_col: Optional[str] = None

    for col in df.columns:
        lc = col.lower()
        if 'frequency' in lc:
            freq_col = col
        if ("we.z'" in lc or "z'" in lc) and "-" not in lc:
            zreal_col = col
        if ("-z" in lc or "-z" in col) and ("imag" in lc or '"' in col):
            zimag_col = col

    if freq_col is None:
        raise ValueError("Frequency column not found.")

    if zreal_col is None or zimag_col is None:
        # Fallback: assume the second and third columns are real and (negative) imag.
        cols = [c for c in df.columns if c != freq_col]
        if len(cols) >= 2:
            zreal_col = zreal_col or cols[0]
            zimag_col = zimag_col or cols[1]
        else:
            raise ValueError("Could not identify impedance columns.")

    return freq_col, zreal_col, zimag_col


def zarc_impedance(R: float, tau: float, gamma: float, w: np.ndarray) -> np.ndarray:
    """Cole–Cole (Zarc) element: R / (1 + (j ω τ)^γ)."""
    return R / (1 + (1j * w * tau) ** gamma)


def model_Rs_Zarc(params: Sequence[float], w: np.ndarray) -> np.ndarray:
    """Impedance of an Rs + Zarc model."""
    Rs, R, tau, gamma = params
    return Rs + zarc_impedance(R, tau, gamma, w)


def residual_Rs_Zarc(params: Sequence[float], w: np.ndarray, Z: np.ndarray) -> np.ndarray:
    """Concatenated residuals of real and imaginary parts."""
    Zf = model_Rs_Zarc(params, w)
    return np.hstack((Zf.real - Z.real, Zf.imag - Z.imag))


def fit_semicircle(f: np.ndarray, Z: np.ndarray) -> np.ndarray:
    """Fit Rs + Zarc to the provided frequency window.

    Initial guesses:
      Rs0  := min(Re(Z))
      R0   := max(Re(Z)) - Rs0   (clamped to ≥ 1 if nonpositive)
      tau0 := 1 / ω_peak where ω_peak is at max(-Im(Z))
      γ0   := 0.8

    Bounds:
      Rs ≥ 0, R ≥ 0, tau ≥ 1e-9, 0 ≤ γ ≤ 1
    """
    w = 2 * np.pi * f

    Rs0 = float(np.min(Z.real))
    R0 = float(np.max(Z.real) - Rs0)
    if R0 <= 0:
        R0 = 1.0

    idx_peak = int(np.argmax(-Z.imag)) if Z.size > 0 else 0
    w_peak = float(w[idx_peak]) if idx_peak < w.size else 1.0
    tau0 = 1.0 / w_peak if w_peak > 0 else 1e-3

    init = [Rs0, R0, 1.0 * tau0, 0.8]
    lower = [0, 0, 1e-9, 0.0]
    upper = [np.inf, np.inf, np.inf, 1.0]

    res = least_squares(
        residual_Rs_Zarc, init, bounds=(lower, upper), args=(w, Z), max_nfev=20000
    )
    return res.x  # [Rs, R, tau, gamma]


def process_file(
    filepath: str,
    freq_window: Tuple[float, float] = (1000.0, 5000.0),
    freq_points: Optional[Sequence[float]] = None,
    show_plot: bool = False,
) -> Optional[Dict[str, float]]:
    """Process a single CSV file and save outputs next to it.

    - Reads CSV
    - Identifies frequency / Z′ / (−Z″) columns
    - Selects the 1–5 kHz window
    - Fits Rs + Zarc
    - Evaluates model at fixed frequencies
    - Saves a summary CSV and a Nyquist plot PNG

    Parameters
    ----------
    filepath : str
    freq_window : (float, float)
    freq_points : sequence of float or None
        If None, uses [1000, 1500, ..., 5000].
    show_plot : bool
        If True, display the Nyquist plot inline (in addition to saving it).

    Returns
    -------
    dict with fitted parameters and output paths, or None if skipped/failed.
    """
    if freq_points is None:
        freq_points = [1000.0, 1500.0, 2000.0, 2500.0, 3000.0, 3500.0, 4000.0, 4500.0, 5000.0]

    # Load data
    df = pd.read_csv(filepath)

    # Identify columns
    try:
        freq_col, zreal_col, zimag_col = identify_columns(df)
    except ValueError as e:
        print(f"Skipping {filepath}: {e}")
        return None

    # Build complex impedance (note: input imag column is −Z″)
    f = df[freq_col].astype(float).to_numpy()
    Z_real = df[zreal_col].astype(float).to_numpy()
    Z_neg_imag = df[zimag_col].astype(float).to_numpy()
    Z = Z_real + 1j * (-Z_neg_imag)

    # Select frequency window
    fmin, fmax = freq_window
    mask = (f >= fmin) & (f <= fmax)
    if not np.any(mask):
        print(f"No data in the specified frequency window {freq_window} for {filepath}.")
        return None

    f_sub = f[mask]
    Z_sub = Z[mask]

    # Fit
    params = fit_semicircle(f_sub, Z_sub)
    Rs, R, tau, gamma = [float(p) for p in params]

    # Predictions at requested points
    freq_pts = np.array(freq_points, dtype=float)
    w_pts = 2 * np.pi * freq_pts
    Z_pred = model_Rs_Zarc(params, w_pts)
    summary = pd.DataFrame({
        'Frequency (Hz)': freq_pts,
        "Z' (Ω)": Z_pred.real,
        "-Z'' (Ω)": -Z_pred.imag,
        '|Z| (Ω)': np.abs(Z_pred),
        '-Phase (deg)': -np.degrees(np.angle(Z_pred)),
    })

    # Write summary CSV
    base = os.path.splitext(os.path.basename(filepath))[0]
    #out_csv_name = f"{base}_1000-5000_fit.csv"
    out_csv_name = "single_frequency_summary.csv"

    out_csv_path = os.path.join(os.path.dirname(filepath), out_csv_name)
    summary.to_csv(out_csv_path, index=False)

    # Nyquist plot over the fitted region (conventional descending frequency)
    w_sub = 2 * np.pi * f_sub
    Z_fit_sub = model_Rs_Zarc(params, w_sub)
    order = np.argsort(f_sub)[::-1]

    plt.figure(figsize=(6, 6))
    plt.plot(Z_sub.real, -Z_sub.imag, 'o', markersize=4, label='Data')
    plt.plot(Z_fit_sub.real[order], -Z_fit_sub.imag[order], '-', label='Fit')
    plt.xlabel("Z' (Ω)")
    plt.ylabel("-Z'' (Ω)")
    plt.title('Nyquist plot (1000–5000 Hz)')
    plt.legend()
    plt.tight_layout()

    out_png_name = f"{base}_1000-5000_fit.png"
    out_png_path = os.path.join(os.path.dirname(filepath), out_png_name)
    plt.savefig(out_png_path, dpi=200)
    if show_plot:
        plt.show()
    plt.close()

    print(f"Processed {os.path.basename(filepath)} → {os.path.basename(out_csv_path)}, {os.path.basename(out_png_path)}")

    return {
        "file": filepath,
        "out_csv": out_csv_path,
        "out_png": out_png_path,
        "Rs": Rs,
        "R": R,
        "tau": tau,
        "gamma": gamma,
    }


def scan_directory(root_dir: str, suffix: str = "_2", **process_kwargs) -> List[Dict[str, float]]:
    """Traverse the directory tree and process eligible CSV files.

    Parameters
    ----------
    root_dir : str
        Top-level folder containing concentration and temperature subfolders.
    suffix : str
        Only CSVs whose *basename* ends with this suffix are processed.
    **process_kwargs :
        Forwarded to `process_file` (e.g., show_plot=True).

    Returns
    -------
    List of result dicts (one per processed file).
    """
    results: List[Dict[str, float]] = []

    # Walk one level into concentration dirs, then one level into temperature dirs
    for conc in sorted(os.listdir(root_dir)):
        conc_path = os.path.join(root_dir, conc)
        if not os.path.isdir(conc_path):
            continue

        for temp in sorted(os.listdir(conc_path)):
            temp_path = os.path.join(conc_path, temp)
            if not os.path.isdir(temp_path):
                continue

            for fname in sorted(os.listdir(temp_path)):
                if not fname.lower().endswith('.csv'):
                    continue
                base, _ = os.path.splitext(fname)
                if not base.endswith(suffix):
                    continue

                file_path = os.path.join(temp_path, fname)
                try:
                    out = process_file(file_path, **process_kwargs)
                    if out is not None:
                        results.append(out)
                except Exception as exc:
                    print(f"Error processing {file_path}: {exc}")

    if not results:
        print("No files processed. Check your folder path and filename suffix.")
    return results


# --- Run the batch if ROOT_DIR is valid (safe for notebooks) ---
if os.path.isdir(ROOT_DIR):
    _results = scan_directory(ROOT_DIR, show_plot=False)  # set show_plot=True to display each Nyquist plot inline
else:
    print(f"Set ROOT_DIR to a valid folder; current value not found:\n{ROOT_DIR}")
# Out:
# Processed EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800_2_1000-5000_fit.png
# Error processing /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-C,T/1mM/26C/._EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_2.csv: 'utf-8' codec can't decode byte 0xb0 in position 37: invalid start byte
# Processed EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_38C_40kHz_0.1Hz_pH=2.190_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_38C_40kHz_0.1Hz_pH=2.190_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_40C_40kHz_0.1Hz_pH=2.191_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_40C_40kHz_0.1Hz_pH=2.191_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_42C_40kHz_0.1Hz_pH=2.192_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_42C_40kHz_0.1Hz_pH=2.192_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_44C_40kHz_0.1Hz_pH=2.191_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_44C_40kHz_0.1Hz_pH=2.191_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_46C_40kHz_0.1Hz_pH=2.191_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_46C_40kHz_0.1Hz_pH=2.191_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_48C_40kHz_0.1Hz_pH=2.188_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_48C_40kHz_0.1Hz_pH=2.188_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_5mM_H2SO4_50C_40kHz_0.1Hz_pH=2.186_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_5mM_H2SO4_50C_40kHz_0.1Hz_pH=2.186_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_26C_40kHz_0.1Hz_pH=2.084_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_26C_40kHz_0.1Hz_pH=2.084_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_28C_40kHz_0.1Hz_pH=2.085_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_28C_40kHz_0.1Hz_pH=2.085_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_30C_40kHz_0.1Hz_pH=2.088_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_30C_40kHz_0.1Hz_pH=2.088_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_32C_40kHz_0.1Hz_pH=2.094_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_32C_40kHz_0.1Hz_pH=2.094_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_34C_40kHz_0.1Hz_pH=2.092_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_34C_40kHz_0.1Hz_pH=2.092_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_36C_40kHz_0.1Hz_pH=2.094_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_36C_40kHz_0.1Hz_pH=2.094_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_38C_40kHz_0.1Hz_pH=2.094_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_38C_40kHz_0.1Hz_pH=2.094_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_40C_40kHz_0.1Hz_pH=2.095_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_40C_40kHz_0.1Hz_pH=2.095_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_42C_40kHz_0.1Hz_pH=2.094_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_42C_40kHz_0.1Hz_pH=2.094_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_44C_40kHz_0.1Hz_pH=2.095_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_44C_40kHz_0.1Hz_pH=2.095_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_46C_40kHz_0.1Hz_pH=2.095_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_46C_40kHz_0.1Hz_pH=2.095_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_48C_40kHz_0.1Hz_pH=2.096_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_48C_40kHz_0.1Hz_pH=2.096_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_6mM_H2SO4_50C_40kHz_0.1Hz_pH=2.099_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_6mM_H2SO4_50C_40kHz_0.1Hz_pH=2.099_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_26C_50kHz_0.1Hz_pH=2.020_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_26C_50kHz_0.1Hz_pH=2.020_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_28C_50kHz_0.1Hz_pH=2.020_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_28C_50kHz_0.1Hz_pH=2.020_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_30C_50kHz_0.1Hz_pH=2.025_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_30C_50kHz_0.1Hz_pH=2.025_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924_2_1000-5000_fit.png
# Processed EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927_2.csv → single_frequency_summary.csv, EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927_2_1000-5000_fit.png

# %% [markdown]
# # This block of code, takes the single frequencies, averages and make similar csv as previous code

# %%
# --- Single-frequency folder aggregator (robust) ---

import os, re
from typing import Dict, List, Optional, Tuple
import numpy as np
import pandas as pd

def identify_columns(df: pd.DataFrame) -> Tuple[Optional[str], str, str]:
    """
    Return (freq_col or None, zreal_col, neg_zimag_col) by matching typical EIS headers,
    e.g. "WE.Z' (Ω)" and 'WE.-Z" (Ω)'. Tolerates WE. prefix, Ω/°, and unicode minus.
    """
    cols = list(df.columns)

    def norm(s: str) -> str:
        s = s.replace("−", "-")            # unicode minus -> ascii
        s = s.replace("Ω", "ohm").replace("°", "deg")
        return s.lower()

    # Z' (real)
    zreal = None
    for c in cols:
        nc = norm(c)
        if "z'" in nc or "z prime" in nc or "zreal" in nc or "z re" in nc or "z_re" in nc:
            zreal = c
            break

    # -Z'' (negative imaginary)
    zim_neg = None
    for c in cols:
        nc = norm(c)
        if "-z\"" in nc or "-z''" in nc or "minus z" in nc:
            zim_neg = c
            break
    # Fallback: if only Z'' exists, use it (we'll flip sign later if needed)
    if zim_neg is None:
        for c in cols:
            nc = norm(c)
            if "z\"" in nc or "z''" in nc or "z_im" in nc or "zim" in nc:
                zim_neg = c
                break

    # Frequency (optional)
    fcol = None
    for c in cols:
        if "freq" in norm(c):
            fcol = c
            break

    if zreal is None or zim_neg is None:
        raise ValueError(f"Could not identify Z columns. Found: {cols}")
    return fcol, zreal, zim_neg

def extract_frequency_from_name(filename: str) -> float:
    m = re.search(r'(\d+(?:\.\d+)?)\s*Hz', filename, flags=re.IGNORECASE)
    if not m:
        raise ValueError(f"Could not parse frequency from filename: {filename}")
    return float(m.group(1))

def average_single_frequency_csv(csv_path: str) -> Dict[str, float]:
    df = pd.read_csv(csv_path, encoding="utf-8")
    freq_col, zreal_col, zimag_neg_col = identify_columns(df)

    zr   = pd.to_numeric(df[zreal_col], errors='coerce')
    zneg = pd.to_numeric(df[zimag_neg_col], errors='coerce')

    # Average (ignore NaNs)
    zr_mean   = float(np.nanmean(zr))
    zneg_mean = float(np.nanmean(zneg))

    # Zbar with your convention (input column is -Z'')
    Zbar = zr_mean + 1j * (-zneg_mean)
    mag = float(np.abs(Zbar))
    minus_phase_deg = float(-np.degrees(np.angle(Zbar)))

    freq = extract_frequency_from_name(os.path.basename(csv_path))

    return {
        "Frequency (Hz)": freq,
        "Z' (Ω)": zr_mean,
        "-Z'' (Ω)": zneg_mean,
        "|Z| (Ω)": mag,
        "-Phase (deg)": minus_phase_deg,
    }

def process_single_frequency_folder(folder: str,
                                    outfile_name: str = "single_frequency_summary.csv",
                                    verbose: bool = True) -> Optional[pd.DataFrame]:
    if not os.path.isdir(folder):
        if verbose: print(f"[skip] Not a folder: {folder}")
        return None

    rows: List[Dict[str, float]] = []
    # >>> ignore AppleDouble '._' files and our own output file
    csvs = [f for f in os.listdir(folder)
            if f.lower().endswith(".csv")
            and not f.startswith("._")
            and f != outfile_name]

    if not csvs:
        if verbose: print(f"[info] No CSVs in: {folder}")
        return None

    for fname in sorted(csvs):
        fpath = os.path.join(folder, fname)
        try:
            row = average_single_frequency_csv(fpath)
            rows.append(row)
            if verbose:
                print(f"[ok] Averaged {fname} @ {row['Frequency (Hz)']:.0f} Hz")
        except Exception as e:
            if verbose:
                print(f"[warn] Skipping {fname}: {e}")

    if not rows:
        if verbose: print(f"[info] No valid rows produced in: {folder}")
        return None

    out = pd.DataFrame(rows).sort_values("Frequency (Hz)").reset_index(drop=True)
    out_path = os.path.join(folder, outfile_name)
    out.to_csv(out_path, index=False)
    if verbose:
        print(f"[done] Wrote {outfile_name} with {len(out)} rows in {folder}")
    return out

def process_all_single_frequency(root_dir: str,
                                 conc_whitelist=("14mM","15mM","16mM","17mM","18mM","19mM","20mM"),
                                 single_folder_name: str = "single-frequency",
                                 outfile_name: str = "single_frequency_summary.csv",
                                 verbose: bool = True):
    results: Dict[str, Optional[pd.DataFrame]] = {}
    for conc in sorted(os.listdir(root_dir)):
        if conc not in conc_whitelist:
            continue
        conc_path = os.path.join(root_dir, conc)
        if not os.path.isdir(conc_path):
            continue
        for temp in sorted(os.listdir(conc_path)):
            temp_path = os.path.join(conc_path, temp)
            if not os.path.isdir(temp_path):
                continue
            sf_path = os.path.join(temp_path, single_folder_name)
            df = process_single_frequency_folder(sf_path, outfile_name=outfile_name, verbose=verbose)
            results[sf_path] = df
    return results

# Example:
ROOT_DIR = r"/Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole"
all_results = process_all_single_frequency(ROOT_DIR)
# Out:
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_1000Hz_pH=1.729.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_1500Hz_pH=1.729.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_2000Hz_pH=1.729.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_2500Hz_pH=1.729.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_3000Hz_pH=1.729.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_3500Hz_pH=1.729.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_4000Hz_pH=1.729.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_4500Hz_pH=1.729.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_26C_5000Hz_pH=1.729.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/26C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_1000Hz_pH=1.734.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_1500Hz_pH=1.734.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_2000Hz_pH=1.734.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_2500Hz_pH=1.734.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_3000Hz_pH=1.734.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_3500Hz_pH=1.734.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_4000Hz_pH=1.734.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_4500Hz_pH=1.734.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_28C_5000Hz_pH=1.734.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/28C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_1000Hz_pH=1.738.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_1500Hz_pH=1.738.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_2000Hz_pH=1.738.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_2500Hz_pH=1.738.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_3000Hz_pH=1.738.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_3500Hz_pH=1.738.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_4000Hz_pH=1.738.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_4500Hz_pH=1.738.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_30C_5000Hz_pH=1.738.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/30C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_1000Hz_pH=1.738.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_1500Hz_pH=1.738.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_2000Hz_pH=1.738.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_2500Hz_pH=1.738.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_3000Hz_pH=1.738.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_3500Hz_pH=1.738.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_4000Hz_pH=1.738.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_4500Hz_pH=1.738.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_32C_5000Hz_pH=1.738.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/32C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_1000Hz_pH=1.740.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_1500Hz_pH=1.740.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_2000Hz_pH=1.740.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_2500Hz_pH=1.740.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_3000Hz_pH=1.740.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_3500Hz_pH=1.740.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_4000Hz_pH=1.740.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_4500Hz_pH=1.740.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_34C_5000Hz_pH=1.740.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/34C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_1000Hz_pH=1.744.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_1500Hz_pH=1.744.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_2000Hz_pH=1.744.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_2500Hz_pH=1.744.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_3000Hz_pH=1.744.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_3500Hz_pH=1.744.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_4000Hz_pH=1.744.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_4500Hz_pH=1.744.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_36C_5000Hz_pH=1.744.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/36C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_1000Hz_pH=1.750.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_1500Hz_pH=1.750.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_2000Hz_pH=1.750.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_2500Hz_pH=1.750.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_3000Hz_pH=1.750.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_3500Hz_pH=1.750.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_4000Hz_pH=1.750.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_4500Hz_pH=1.750.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_38C_5000Hz_pH=1.750.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/38C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_1000Hz_pH=1.752.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_1500Hz_pH=1.752.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_2000Hz_pH=1.752.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_2500Hz_pH=1.752.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_3000Hz_pH=1.752.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_3500Hz_pH=1.752.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_4000Hz_pH=1.752.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_4500Hz_pH=1.752.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_40C_5000Hz_pH=1.752.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/40C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_1000Hz_pH=1.755.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_1500Hz_pH=1.755.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_2000Hz_pH=1.755.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_2500Hz_pH=1.755.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_3000Hz_pH=1.755.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_3500Hz_pH=1.755.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_4000Hz_pH=1.755.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_4500Hz_pH=1.755.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_42C_5000Hz_pH=1.755.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/42C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_1000Hz_pH=1.760.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_1500Hz_pH=1.760.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_2000Hz_pH=1.760.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_2500Hz_pH=1.760.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_3000Hz_pH=1.760.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_3500Hz_pH=1.760.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_4000Hz_pH=1.760.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_4500Hz_pH=1.760.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_44C_5000Hz_pH=1.760.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/44C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_1000Hz_pH=1.764.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_1500Hz_pH=1.764.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_2000Hz_pH=1.764.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_2500Hz_pH=1.764.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_3000Hz_pH=1.764.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_3500Hz_pH=1.764.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_4000Hz_pH=1.764.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_4500Hz_pH=1.764.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_46C_5000Hz_pH=1.764.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/46C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_1000Hz_pH=1.766.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_1500Hz_pH=1.766.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_2000Hz_pH=1.766.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_2500Hz_pH=1.766.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_3000Hz_pH=1.766.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_3500Hz_pH=1.766.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_4000Hz_pH=1.766.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_4500Hz_pH=1.766.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_48C_5000Hz_pH=1.766.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/48C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_1000Hz_pH=1.770.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_1500Hz_pH=1.770.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_2000Hz_pH=1.770.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_2500Hz_pH=1.770.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_3000Hz_pH=1.770.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_3500Hz_pH=1.770.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_4000Hz_pH=1.770.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_4500Hz_pH=1.770.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_14mM_H2SO4_50C_5000Hz_pH=1.770.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/50C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_1000Hz_pH=1.702.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_1500Hz_pH=1.702.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_2000Hz_pH=1.702.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_2500Hz_pH=1.702.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_3000Hz_pH=1.702.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_3500Hz_pH=1.702.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_4000Hz_pH=1.702.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_4500Hz_pH=1.702.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_26C_5000Hz_pH=1.702.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/26C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_1000Hz_pH=1.707.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_1500Hz_pH=1.707.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_2000Hz_pH=1.707.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_2500Hz_pH=1.707.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_3000Hz_pH=1.707.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_3500Hz_pH=1.707.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_4000Hz_pH=1.707.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_4500Hz_pH=1.707.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_28C_5000Hz_pH=1.707.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/28C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_1000Hz_pH=1.709.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_1500Hz_pH=1.709.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_2000Hz_pH=1.709.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_2500Hz_pH=1.709.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_3000Hz_pH=1.709.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_3500Hz_pH=1.709.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_4000Hz_pH=1.709.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_4500Hz_pH=1.709.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_30C_5000Hz_pH=1.709.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/30C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_1000Hz_pH=1.711.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_1500Hz_pH=1.711.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_2000Hz_pH=1.711.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_2500Hz_pH=1.711.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_3000Hz_pH=1.711.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_3500Hz_pH=1.711.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_4000Hz_pH=1.711.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_4500Hz_pH=1.711.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_32C_5000Hz_pH=1.711.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/32C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_1000Hz_pH=1.712.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_1500Hz_pH=1.712.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_2000Hz_pH=1.712.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_2500Hz_pH=1.712.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_3000Hz_pH=1.712.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_3500Hz_pH=1.712.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_4000Hz_pH=1.712.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_4500Hz_pH=1.712.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_34C_5000Hz_pH=1.712.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/34C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_1000Hz_pH=1.717.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_1500Hz_pH=1.717.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_2000Hz_pH=1.717.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_2500Hz_pH=1.717.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_3000Hz_pH=1.717.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_3500Hz_pH=1.717.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_4000Hz_pH=1.717.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_4500Hz_pH=1.717.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_36C_5000Hz_pH=1.717.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/36C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_1000Hz_pH=1.723.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_1500Hz_pH=1.723.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_2000Hz_pH=1.723.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_2500Hz_pH=1.723.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_3000Hz_pH=1.723.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_3500Hz_pH=1.723.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_4000Hz_pH=1.723.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_4500Hz_pH=1.723.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_38C_5000Hz_pH=1.723.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/38C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_1000Hz_pH=1.726.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_1500Hz_pH=1.726.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_2000Hz_pH=1.726.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_2500Hz_pH=1.726.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_3000Hz_pH=1.726.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_3500Hz_pH=1.726.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_4000Hz_pH=1.726.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_4500Hz_pH=1.726.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_40C_5000Hz_pH=1.726.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/40C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_1000Hz_pH=1.730.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_1500Hz_pH=1.730.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_2000Hz_pH=1.730.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_2500Hz_pH=1.730.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_3000Hz_pH=1.730.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_3500Hz_pH=1.730.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_4000Hz_pH=1.730.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_4500Hz_pH=1.730.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_42C_5000Hz_pH=1.730.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/42C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_1000Hz_pH=1.734.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_1500Hz_pH=1.734.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_2000Hz_pH=1.734.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_2500Hz_pH=1.734.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_3000Hz_pH=1.734.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_3500Hz_pH=1.734.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_4000Hz_pH=1.734.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_4500Hz_pH=1.734.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_44C_5000Hz_pH=1.734.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/44C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_1000Hz_pH=1.736.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_1500Hz_pH=1.736.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_2000Hz_pH=1.736.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_2500Hz_pH=1.736.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_3000Hz_pH=1.736.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_3500Hz_pH=1.736.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_4000Hz_pH=1.736.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_4500Hz_pH=1.736.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_46C_5000Hz_pH=1.736.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/46C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_1000Hz_pH=1.741.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_1500Hz_pH=1.741.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_2000Hz_pH=1.741.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_2500Hz_pH=1.741.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_3000Hz_pH=1.741.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_3500Hz_pH=1.741.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_4000Hz_pH=1.741.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_4500Hz_pH=1.741.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_48C_5000Hz_pH=1.741.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/48C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_1000Hz_pH=1.744.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_1500Hz_pH=1.744.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_2000Hz_pH=1.744.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_2500Hz_pH=1.744.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_3000Hz_pH=1.744.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_3500Hz_pH=1.744.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_4000Hz_pH=1.744.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_4500Hz_pH=1.744.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_15mM_H2SO4_50C_5000Hz_pH=1.744.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/50C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_1000Hz_pH=1.690.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_1500Hz_pH=1.690.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_2000Hz_pH=1.690.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_2500Hz_pH=1.690.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_3000Hz_pH=1.690.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_3500Hz_pH=1.690.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_4000Hz_pH=1.690.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_4500Hz_pH=1.690.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_26C_5000Hz_pH=1.690.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/26C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_1000Hz_pH=1.696.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_1500Hz_pH=1.696.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_2000Hz_pH=1.696.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_2500Hz_pH=1.696.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_3000Hz_pH=1.696.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_3500Hz_pH=1.696.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_4000Hz_pH=1.696.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_4500Hz_pH=1.696.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_28C_5000Hz_pH=1.696.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/28C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_1000Hz_pH=1.702.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_1500Hz_pH=1.702.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_2000Hz_pH=1.702.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_2500Hz_pH=1.702.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_3000Hz_pH=1.702.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_3500Hz_pH=1.702.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_4000Hz_pH=1.702.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_4500Hz_pH=1.702.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_30C_5000Hz_pH=1.702.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/30C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_1000Hz_pH=1.707.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_1500Hz_pH=1.707.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_2000Hz_pH=1.707.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_2500Hz_pH=1.707.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_3000Hz_pH=1.707.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_3500Hz_pH=1.707.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_4000Hz_pH=1.707.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_4500Hz_pH=1.707.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_32C_5000Hz_pH=1.707.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/32C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_1000Hz_pH=1.710.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_1500Hz_pH=1.710.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_2000Hz_pH=1.710.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_2500Hz_pH=1.710.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_3000Hz_pH=1.710.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_3500Hz_pH=1.710.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_4000Hz_pH=1.710.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_4500Hz_pH=1.710.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_34C_5000Hz_pH=1.710.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/34C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_1000Hz_pH=1.711.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_1500Hz_pH=1.711.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_2000Hz_pH=1.711.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_2500Hz_pH=1.711.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_3000Hz_pH=1.711.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_3500Hz_pH=1.711.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_4000Hz_pH=1.711.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_4500Hz_pH=1.711.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_36C_5000Hz_pH=1.711.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/36C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_1000Hz_pH=1.711.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_1500Hz_pH=1.711.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_2000Hz_pH=1.711.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_2500Hz_pH=1.711.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_3000Hz_pH=1.711.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_3500Hz_pH=1.711.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_4000Hz_pH=1.711.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_4500Hz_pH=1.711.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_38C_5000Hz_pH=1.711.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/38C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_1000Hz_pH=1.712.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_1500Hz_pH=1.712.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_2000Hz_pH=1.712.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_2500Hz_pH=1.712.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_3000Hz_pH=1.712.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_3500Hz_pH=1.712.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_4000Hz_pH=1.712.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_4500Hz_pH=1.712.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_40C_5000Hz_pH=1.712.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/40C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_1000Hz_pH=1.711.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_1500Hz_pH=1.711.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_2000Hz_pH=1.711.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_2500Hz_pH=1.711.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_3000Hz_pH=1.711.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_3500Hz_pH=1.711.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_4000Hz_pH=1.711.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_4500Hz_pH=1.711.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_42C_5000Hz_pH=1.711.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/42C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_1000Hz_pH=1.712.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_1500Hz_pH=1.712.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_2000Hz_pH=1.712.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_2500Hz_pH=1.712.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_3000Hz_pH=1.712.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_3500Hz_pH=1.712.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_4000Hz_pH=1.712.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_4500Hz_pH=1.712.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_44C_5000Hz_pH=1.712.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/44C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_1000Hz_pH=1.712.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_1500Hz_pH=1.712.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_2000Hz_pH=1.712.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_2500Hz_pH=1.712.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_3000Hz_pH=1.712.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_3500Hz_pH=1.712.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_4000Hz_pH=1.712.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_4500Hz_pH=1.712.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_46C_5000Hz_pH=1.712.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/46C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_1000Hz_pH=1.716.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_1500Hz_pH=1.716.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_2000Hz_pH=1.716.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_2500Hz_pH=1.716.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_3000Hz_pH=1.716.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_3500Hz_pH=1.716.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_4000Hz_pH=1.716.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_4500Hz_pH=1.716.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_48C_5000Hz_pH=1.716.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/48C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_1000Hz_pH=1.719.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_1500Hz_pH=1.719.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_2000Hz_pH=1.719.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_2500Hz_pH=1.719.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_3000Hz_pH=1.719.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_3500Hz_pH=1.719.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_4000Hz_pH=1.719.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_4500Hz_pH=1.719.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_16mM_H2SO4_50C_5000Hz_pH=1.719.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/50C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_1000Hz_pH=1.656.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_1500Hz_pH=1.656.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_2000Hz_pH=1.656.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_2500Hz_pH=1.656.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_3000Hz_pH=1.656.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_3500Hz_pH=1.656.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_4000Hz_pH=1.656.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_4500Hz_pH=1.656.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_26C_5000Hz_pH=1.656.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/26C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_1000Hz_pH=1.659.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_1500Hz_pH=1.659.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_2000Hz_pH=1.659.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_2500Hz_pH=1.659.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_3000Hz_pH=1.659.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_3500Hz_pH=1.659.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_4000Hz_pH=1.659.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_4500Hz_pH=1.659.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_28C_5000Hz_pH=1.659.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/28C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_1000Hz_pH=1.662.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_1500Hz_pH=1.662.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_2000Hz_pH=1.662.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_2500Hz_pH=1.662.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_3000Hz_pH=1.662.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_3500Hz_pH=1.662.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_4000Hz_pH=1.662.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_4500Hz_pH=1.662.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_30C_5000Hz_pH=1.662.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/30C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_1000Hz_pH=1.662.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_1500Hz_pH=1.662.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_2000Hz_pH=1.662.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_2500Hz_pH=1.662.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_3000Hz_pH=1.662.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_3500Hz_pH=1.662.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_4000Hz_pH=1.662.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_4500Hz_pH=1.662.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_32C_5000Hz_pH=1.662.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/32C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_1000Hz_pH=1.661.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_1500Hz_pH=1.661.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_2000Hz_pH=1.661.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_2500Hz_pH=1.661.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_3000Hz_pH=1.661.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_3500Hz_pH=1.661.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_4000Hz_pH=1.661.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_4500Hz_pH=1.661.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_34C_5000Hz_pH=1.661.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/34C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_1000Hz_pH=1.666.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_1500Hz_pH=1.666.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_2000Hz_pH=1.666.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_2500Hz_pH=1.666.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_3000Hz_pH=1.666.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_3500Hz_pH=1.666.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_4000Hz_pH=1.666.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_4500Hz_pH=1.666.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_36C_5000Hz_pH=1.666.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/36C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_1000Hz_pH=1.670.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_1500Hz_pH=1.670.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_2000Hz_pH=1.670.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_2500Hz_pH=1.670.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_3000Hz_pH=1.670.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_3500Hz_pH=1.670.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_4000Hz_pH=1.670.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_4500Hz_pH=1.670.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_38C_5000Hz_pH=1.670.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/38C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_1000Hz_pH=1.675.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_1500Hz_pH=1.675.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_2000Hz_pH=1.675.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_2500Hz_pH=1.675.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_3000Hz_pH=1.675.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_3500Hz_pH=1.675.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_4000Hz_pH=1.675.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_4500Hz_pH=1.675.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_40C_5000Hz_pH=1.675.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/40C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_1000Hz_pH=1.678.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_1500Hz_pH=1.678.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_2000Hz_pH=1.678.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_2500Hz_pH=1.678.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_3000Hz_pH=1.678.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_3500Hz_pH=1.678.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_4000Hz_pH=1.678.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_4500Hz_pH=1.678.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_42C_5000Hz_pH=1.678.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/42C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_1000Hz_pH=1.682.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_1500Hz_pH=1.682.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_2000Hz_pH=1.682.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_2500Hz_pH=1.682.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_3000Hz_pH=1.682.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_3500Hz_pH=1.682.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_4000Hz_pH=1.682.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_4500Hz_pH=1.682.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_17mM_H2SO4_44C_5000Hz_pH=1.682.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/44C/single-frequency
# ...
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_44C_4500Hz_pH=1.649.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_44C_5000Hz_pH=1.649.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/44C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_1000Hz_pH=1.655.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_1500Hz_pH=1.655.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_2000Hz_pH=1.655.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_2500Hz_pH=1.655.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_3000Hz_pH=1.655.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_3500Hz_pH=1.655.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_4000Hz_pH=1.655.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_4500Hz_pH=1.655.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_46C_5000Hz_pH=1.655.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/46C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_1000Hz_pH=1.657.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_1500Hz_pH=1.657.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_2000Hz_pH=1.657.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_2500Hz_pH=1.657.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_3000Hz_pH=1.657.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_3500Hz_pH=1.657.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_4000Hz_pH=1.657.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_4500Hz_pH=1.657.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_48C_5000Hz_pH=1.657.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/48C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_1000Hz_pH=1.661.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_1500Hz_pH=1.661.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_2000Hz_pH=1.661.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_2500Hz_pH=1.661.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_3000Hz_pH=1.661.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_3500Hz_pH=1.661.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_4000Hz_pH=1.661.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_4500Hz_pH=1.661.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_19mM_H2SO4_50C_5000Hz_pH=1.661.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/50C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_1000Hz_pH=1.600.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_1500Hz_pH=1.600.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_2000Hz_pH=1.600.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_2500Hz_pH=1.600.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_3000Hz_pH=1.600.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_3500Hz_pH=1.600.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_4000Hz_pH=1.600.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_4500Hz_pH=1.600.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_26C_5000Hz_pH=1.600.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/26C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_1000Hz_pH=1.603.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_1500Hz_pH=1.603.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_2000Hz_pH=1.603.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_2500Hz_pH=1.603.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_3000Hz_pH=1.603.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_3500Hz_pH=1.603.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_4000Hz_pH=1.603.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_4500Hz_pH=1.603.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_28C_5000Hz_pH=1.603.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/28C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_1000Hz_pH=1.610.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_1500Hz_pH=1.610.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_2000Hz_pH=1.610.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_2500Hz_pH=1.610.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_3000Hz_pH=1.610.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_3500Hz_pH=1.610.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_4000Hz_pH=1.610.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_4500Hz_pH=1.610.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_30C_5000Hz_pH=1.610.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/30C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_1000Hz_pH=1.617.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_1500Hz_pH=1.617.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_2000Hz_pH=1.617.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_2500Hz_pH=1.617.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_3000Hz_pH=1.617.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_3500Hz_pH=1.617.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_4000Hz_pH=1.617.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_4500Hz_pH=1.617.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_32C_5000Hz_pH=1.617.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/32C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_1000Hz_pH=1.619.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_1500Hz_pH=1.619.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_2000Hz_pH=1.619.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_2500Hz_pH=1.619.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_3000Hz_pH=1.619.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_3500Hz_pH=1.619.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_4000Hz_pH=1.619.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_4500Hz_pH=1.619.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_34C_5000Hz_pH=1.619.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/34C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_1000Hz_pH=1.620.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_1500Hz_pH=1.620.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_2000Hz_pH=1.620.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_2500Hz_pH=1.620.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_3000Hz_pH=1.620.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_3500Hz_pH=1.620.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_4000Hz_pH=1.620.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_4500Hz_pH=1.620.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_36C_5000Hz_pH=1.620.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/36C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_1000Hz_pH=1.624.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_1500Hz_pH=1.624.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_2000Hz_pH=1.624.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_2500Hz_pH=1.624.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_3000Hz_pH=1.624.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_3500Hz_pH=1.624.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_4000Hz_pH=1.624.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_4500Hz_pH=1.624.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_38C_5000Hz_pH=1.624.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/38C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_1000Hz_pH=1.628.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_1500Hz_pH=1.628.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_2000Hz_pH=1.628.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_2500Hz_pH=1.628.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_3000Hz_pH=1.628.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_3500Hz_pH=1.628.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_4000Hz_pH=1.628.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_4500Hz_pH=1.628.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_40C_5000Hz_pH=1.628.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/40C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_1000Hz_pH=1.631.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_1500Hz_pH=1.631.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_2000Hz_pH=1.631.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_2500Hz_pH=1.631.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_3000Hz_pH=1.631.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_3500Hz_pH=1.631.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_4000Hz_pH=1.631.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_4500Hz_pH=1.631.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_42C_5000Hz_pH=1.631.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/42C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_1000Hz_pH=1.635.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_1500Hz_pH=1.635.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_2000Hz_pH=1.635.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_2500Hz_pH=1.635.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_3000Hz_pH=1.635.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_3500Hz_pH=1.635.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_4000Hz_pH=1.635.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_4500Hz_pH=1.635.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_44C_5000Hz_pH=1.635.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/44C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_1000Hz_pH=1.639.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_1500Hz_pH=1.639.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_2000Hz_pH=1.639.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_2500Hz_pH=1.639.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_3000Hz_pH=1.639.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_3500Hz_pH=1.639.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_4000Hz_pH=1.639.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_4500Hz_pH=1.639.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_46C_5000Hz_pH=1.639.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/46C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_1000Hz_pH=1.643.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_1500Hz_pH=1.643.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_2000Hz_pH=1.643.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_2500Hz_pH=1.643.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_3000Hz_pH=1.643.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_3500Hz_pH=1.643.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_4000Hz_pH=1.643.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_4500Hz_pH=1.643.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_48C_5000Hz_pH=1.643.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/48C/single-frequency
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_1000Hz_pH=1.648.csv @ 1000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_1500Hz_pH=1.648.csv @ 1500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_2000Hz_pH=1.648.csv @ 2000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_2500Hz_pH=1.648.csv @ 2500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_3000Hz_pH=1.648.csv @ 3000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_3500Hz_pH=1.648.csv @ 3500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_4000Hz_pH=1.648.csv @ 4000 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_4500Hz_pH=1.648.csv @ 4500 Hz
# [ok] Averaged EIS_capillary_single_frequency_20mM_H2SO4_50C_5000Hz_pH=1.648.csv @ 5000 Hz
# [done] Wrote single_frequency_summary.csv with 9 rows in /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/50C/single-frequency

# %% [markdown]
# # This code takes the file with the name single_frequency_summary.csv from the single-frequency folder, paste it in one folder back, then deletes the folder and moves the dontent of whole-spectrum folder and paste it in one folder back

# %%
# --- Folder cleanup utility: move 'single_frequency_summary.csv' out of 'single-frequency',
#     then delete 'single-frequency', hoist contents of 'whole-spectrum' ---

from pathlib import Path
import shutil, time, os
from typing import Iterable, Dict, Any

# >>>>> SET YOUR ROOT FOLDER HERE <<<<<
ROOT_DIR = Path(r"/Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole")

# Options
CONC_WHITELIST = None  # e.g., {"14mM","15mM","16mM","17mM","18mM","19mM","20mM"} or None for all
DRY_RUN = False         # <-- set to False to actually perform changes
CONFLICT = "rename"     # one of: "rename", "overwrite", "skip"

# Names to match (case-insensitive; underscores/spaces normalized to hyphens)
SINGLE_NAMES = {"single-frequency"}
WHOLE_NAMES  = {"whole-spectrum", "whole-specrtrum"}  # include common typo

SUMMARY_FILENAME = "single_frequency_summary.csv"      # file to extract from 'single-frequency'


# --- helpers (unchanged) ---
def _norm(name: str) -> str:
    s = name.strip().lower().replace("_", "-").replace(" ", "-")
    while "--" in s:
        s = s.replace("--", "-")
    return s

def _find_child_dir(parent: Path, candidates: Iterable[str]) -> Path | None:
    cset = {_norm(c) for c in candidates}
    for child in parent.iterdir():
        if child.is_dir() and _norm(child.name) in cset:
            return child
    return None

def _unique_target(p: Path) -> Path:
    if not p.exists():
        return p
    stem, suffix = (p.stem, p.suffix)
    i = 1
    while True:
        cand = p.with_name(f"{stem} (copy{'' if i==1 else f' {i}'}){suffix}")
        if not cand.exists():
            return cand
        i += 1

def _move_item(src: Path, dst_dir: Path, conflict: str, dry_run: bool) -> Path | None:
    target = dst_dir / src.name
    if target.exists():
        if conflict == "skip":
            print(f"  [skip exists] {target.name}")
            return None
        elif conflict == "overwrite":
            print(f"  [overwrite]   {target.name}")
            if not dry_run:
                if target.is_dir():
                    shutil.rmtree(target)
                else:
                    target.unlink(missing_ok=True)
        elif conflict == "rename":
            new_target = _unique_target(target)
            print(f"  [rename]      {target.name} -> {new_target.name}")
            target = new_target
        else:
            raise ValueError("CONFLICT must be one of: 'rename', 'overwrite', 'skip'")
    else:
        print(f"  [move]        {src.name} -> {dst_dir.name}/")
    if not dry_run:
        shutil.move(str(src), str(target))
    return target

# --- robust delete that tolerates disappearing entries ---
def safe_rmtree(path: Path, retries: int = 3, pause: float = 0.1) -> None:
    for attempt in range(1, retries + 1):
        try:
            shutil.rmtree(path)
            return
        except FileNotFoundError:
            return
        except OSError as e:
            if attempt == retries:
                try:
                    entries = [p.name for p in path.iterdir()] if path.exists() else []
                except Exception:
                    entries = ["<unreadable>"]
                print(f"[error] rmtree failed for: {path}\n         entries: {entries}\n         {e.__class__.__name__}: {e}")
                raise
            time.sleep(pause)

def _find_summary_file(folder: Path, expected_name: str) -> Path | None:
    """
    Return the path to the summary CSV inside `folder` if present.
    - Case-insensitive match on filename.
    - Ignores AppleDouble files that start with '._'.
    """
    expected_lower = expected_name.lower()
    for child in folder.iterdir():
        if child.is_file():
            if child.name.startswith("._"):   # ignore resource-fork files
                continue
            if child.name.lower() == expected_lower:
                return child
    return None

# --- main ---
def tidy_temperature_folders(root_dir: Path,
                             conc_whitelist: set[str] | None = None,
                             single_names = {"single-frequency"},
                             whole_names  = {"whole-spectrum", "whole-specrtrum"},
                             conflict: str = "rename",
                             dry_run: bool = True,
                             summary_filename: str = SUMMARY_FILENAME) -> Dict[str, Any]:
    if not root_dir.is_dir():
        raise FileNotFoundError(f"Root directory not found: {root_dir}")

    actions = {
        "single_deleted": 0,
        "whole_moved": 0,
        "whole_deleted": 0,
        "temps_seen": 0,
        "summaries_extracted": 0,
    }

    for conc_dir in sorted(p for p in root_dir.iterdir() if p.is_dir()):
        if conc_whitelist and conc_dir.name not in conc_whitelist:
            continue

        for temp_dir in sorted(p for p in conc_dir.iterdir() if p.is_dir()):
            actions["temps_seen"] += 1
            print(f"\n== {conc_dir.name} / {temp_dir.name} ==")

            # 1) Extract summary from 'single-frequency', then delete that folder
            single = _find_child_dir(temp_dir, single_names)
            if single and single.exists():
                # Look for the summary file and move it up one level
                summary_path = _find_summary_file(single, summary_filename)
                if summary_path:
                    print(f"[extract] {summary_path.name} from {single.name}/ -> {temp_dir.name}/")
                    out = _move_item(summary_path, temp_dir, conflict=conflict, dry_run=dry_run)
                    if out is not None:
                        actions["summaries_extracted"] += 1
                else:
                    print(f"[info]   {summary_filename} not found in {single.name}/")

                # Now delete 'single-frequency'
                print(f"[delete] single-frequency -> {single}")
                if not dry_run:
                    safe_rmtree(single)
                actions["single_deleted"] += 1
            else:
                print("[info]   single-frequency not found")

            # 2) Move contents of 'whole-spectrum' up one level, then delete it
            whole = _find_child_dir(temp_dir, whole_names)
            if whole and whole.exists():
                for child in sorted(whole.iterdir()):
                    out = _move_item(child, temp_dir, conflict=conflict, dry_run=dry_run)
                    if out is not None:
                        actions["whole_moved"] += 1
                print(f"[delete] whole-spectrum -> {whole}")
                if not dry_run:
                    safe_rmtree(whole)
                actions["whole_deleted"] += 1
            else:
                print("[info]   whole-spectrum not found")

    print("\n--- SUMMARY ---")
    print(f"Temperature folders seen        : {actions['temps_seen']}")
    print(f"Summaries extracted             : {actions['summaries_extracted']}")
    print(f"'single-frequency' deleted      : {actions['single_deleted']}")
    print(f"Items moved from 'whole'        : {actions['whole_moved']}")
    print(f"'whole-spectrum' deleted        : {actions['whole_deleted']}")
    print(f"Dry-run: {dry_run} | Conflict policy: {conflict}")
    return actions


# Call it (prints progress). Start with a dry run or restrict to a concentration to verify.
summary = tidy_temperature_folders(
    ROOT_DIR,
    conc_whitelist=CONC_WHITELIST,  # e.g., {"20mM"} to test only one concentration
    conflict=CONFLICT,
    dry_run=DRY_RUN
)
summary
# Out:
# == 10mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 10mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 11mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 12mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 13mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 14mM / 26C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 26C/
#   [move]        single_frequency_summary.csv -> 26C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/26C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_26C_60kHz_0.1Hz_pH=1.729.csv -> 26C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_26C_60kHz_0.1Hz_pH=1.729.nox -> 26C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/26C/whole-spectrum
#
# == 14mM / 28C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 28C/
#   [move]        single_frequency_summary.csv -> 28C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/28C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_28C_60kHz_0.1Hz_pH=1.734.csv -> 28C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_28C_60kHz_0.1Hz_pH=1.734.nox -> 28C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/28C/whole-spectrum
#
# == 14mM / 30C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 30C/
#   [move]        single_frequency_summary.csv -> 30C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/30C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_30C_60kHz_0.1Hz_pH=1.738.csv -> 30C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_30C_60kHz_0.1Hz_pH=1.738.nox -> 30C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/30C/whole-spectrum
#
# == 14mM / 32C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 32C/
#   [move]        single_frequency_summary.csv -> 32C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/32C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_32C_60kHz_0.1Hz_pH=1.738.csv -> 32C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_32C_60kHz_0.1Hz_pH=1.738.nox -> 32C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/32C/whole-spectrum
#
# == 14mM / 34C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 34C/
#   [move]        single_frequency_summary.csv -> 34C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/34C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_34C_60kHz_0.1Hz_pH=1.740.csv -> 34C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_34C_60kHz_0.1Hz_pH=1.740.nox -> 34C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/34C/whole-spectrum
#
# == 14mM / 36C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 36C/
#   [move]        single_frequency_summary.csv -> 36C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/36C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_36C_60kHz_0.1Hz_pH=1.744.csv -> 36C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_36C_60kHz_0.1Hz_pH=1.744.nox -> 36C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/36C/whole-spectrum
#
# == 14mM / 38C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 38C/
#   [move]        single_frequency_summary.csv -> 38C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/38C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_38C_60kHz_0.1Hz_pH=1.750.csv -> 38C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_38C_60kHz_0.1Hz_pH=1.750.nox -> 38C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/38C/whole-spectrum
#
# == 14mM / 40C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 40C/
#   [move]        single_frequency_summary.csv -> 40C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/40C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_40C_60kHz_0.1Hz_pH=1.752.csv -> 40C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_40C_60kHz_0.1Hz_pH=1.752.nox -> 40C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/40C/whole-spectrum
#
# == 14mM / 42C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 42C/
#   [move]        single_frequency_summary.csv -> 42C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/42C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_42C_60kHz_0.1Hz_pH=1.755.csv -> 42C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_42C_60kHz_0.1Hz_pH=1.755.nox -> 42C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/42C/whole-spectrum
#
# == 14mM / 44C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 44C/
#   [move]        single_frequency_summary.csv -> 44C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/44C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_44C_60kHz_0.1Hz_pH=1.760.csv -> 44C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_44C_60kHz_0.1Hz_pH=1.760.nox -> 44C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/44C/whole-spectrum
#
# == 14mM / 46C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 46C/
#   [move]        single_frequency_summary.csv -> 46C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/46C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_46C_60kHz_0.1Hz_pH=1.764.csv -> 46C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_46C_60kHz_0.1Hz_pH=1.764.nox -> 46C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/46C/whole-spectrum
#
# == 14mM / 48C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 48C/
#   [move]        single_frequency_summary.csv -> 48C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/48C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_48C_60kHz_0.1Hz_pH=1.766.csv -> 48C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_48C_60kHz_0.1Hz_pH=1.766.nox -> 48C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/48C/whole-spectrum
#
# == 14mM / 50C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 50C/
#   [move]        single_frequency_summary.csv -> 50C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/50C/single-frequency
#   [move]        EIS_whole_spectrum_14mM_H2SO4_50C_60kHz_0.1Hz_pH=1.770.csv -> 50C/
#   [move]        EIS_whole_spectrum_14mM_H2SO4_50C_60kHz_0.1Hz_pH=1.770.nox -> 50C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/14mM/50C/whole-spectrum
#
# == 15mM / 26C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 26C/
#   [move]        single_frequency_summary.csv -> 26C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/26C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_26C_70kHz_0.1Hz_pH=1.702.csv -> 26C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_26C_70kHz_0.1Hz_pH=1.702.nox -> 26C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/26C/whole-spectrum
#
# == 15mM / 28C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 28C/
#   [move]        single_frequency_summary.csv -> 28C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/28C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_28C_70kHz_0.1Hz_pH=1.707.csv -> 28C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_28C_70kHz_0.1Hz_pH=1.707.nox -> 28C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/28C/whole-spectrum
#
# == 15mM / 30C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 30C/
#   [move]        single_frequency_summary.csv -> 30C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/30C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_30C_70kHz_0.1Hz_pH=1.709.csv -> 30C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_30C_70kHz_0.1Hz_pH=1.709.nox -> 30C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/30C/whole-spectrum
#
# == 15mM / 32C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 32C/
#   [move]        single_frequency_summary.csv -> 32C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/32C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_32C_70kHz_0.1Hz_pH=1.711.csv -> 32C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_32C_70kHz_0.1Hz_pH=1.711.nox -> 32C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/32C/whole-spectrum
#
# == 15mM / 34C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 34C/
#   [move]        single_frequency_summary.csv -> 34C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/34C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_34C_70kHz_0.1Hz_pH=1.712.csv -> 34C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_34C_70kHz_0.1Hz_pH=1.712.nox -> 34C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/34C/whole-spectrum
#
# == 15mM / 36C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 36C/
#   [move]        single_frequency_summary.csv -> 36C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/36C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_36C_70kHz_0.1Hz_pH=1.717.csv -> 36C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_36C_70kHz_0.1Hz_pH=1.717.nox -> 36C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/36C/whole-spectrum
#
# == 15mM / 38C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 38C/
#   [move]        single_frequency_summary.csv -> 38C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/38C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_38C_70kHz_0.1Hz_pH=1.723.csv -> 38C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_38C_70kHz_0.1Hz_pH=1.723.nox -> 38C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/38C/whole-spectrum
#
# == 15mM / 40C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 40C/
#   [move]        single_frequency_summary.csv -> 40C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/40C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_40C_70kHz_0.1Hz_pH=1.726.csv -> 40C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_40C_70kHz_0.1Hz_pH=1.726.nox -> 40C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/40C/whole-spectrum
#
# == 15mM / 42C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 42C/
#   [move]        single_frequency_summary.csv -> 42C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/42C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_42C_70kHz_0.1Hz_pH=1.730.csv -> 42C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_42C_70kHz_0.1Hz_pH=1.730.nox -> 42C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/42C/whole-spectrum
#
# == 15mM / 44C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 44C/
#   [move]        single_frequency_summary.csv -> 44C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/44C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_44C_70kHz_0.1Hz_pH=1.734.csv -> 44C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_44C_70kHz_0.1Hz_pH=1.734.nox -> 44C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/44C/whole-spectrum
#
# == 15mM / 46C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 46C/
#   [move]        single_frequency_summary.csv -> 46C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/46C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_46C_70kHz_0.1Hz_pH=1.736.csv -> 46C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_46C_70kHz_0.1Hz_pH=1.736.nox -> 46C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/46C/whole-spectrum
#
# == 15mM / 48C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 48C/
#   [move]        single_frequency_summary.csv -> 48C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/48C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_48C_70kHz_0.1Hz_pH=1.741.csv -> 48C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_48C_70kHz_0.1Hz_pH=1.741.nox -> 48C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/48C/whole-spectrum
#
# == 15mM / 50C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 50C/
#   [move]        single_frequency_summary.csv -> 50C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/50C/single-frequency
#   [move]        EIS_whole_spectrum_15mM_H2SO4_50C_70kHz_0.1Hz_pH=1.744.csv -> 50C/
#   [move]        EIS_whole_spectrum_15mM_H2SO4_50C_70kHz_0.1Hz_pH=1.744.nox -> 50C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/15mM/50C/whole-spectrum
#
# == 16mM / 26C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 26C/
#   [move]        single_frequency_summary.csv -> 26C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/26C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_26C_80kHz_0.1Hz_pH=1.690.csv -> 26C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_26C_80kHz_0.1Hz_pH=1.690.nox -> 26C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/26C/whole-spectrum
#
# == 16mM / 28C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 28C/
#   [move]        single_frequency_summary.csv -> 28C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/28C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_28C_80kHz_0.1Hz_pH=1.696.csv -> 28C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_28C_80kHz_0.1Hz_pH=1.696.nox -> 28C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/28C/whole-spectrum
#
# == 16mM / 30C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 30C/
#   [move]        single_frequency_summary.csv -> 30C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/30C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_30C_80kHz_0.1Hz_pH=1.702.csv -> 30C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_30C_80kHz_0.1Hz_pH=1.702.nox -> 30C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/30C/whole-spectrum
#
# == 16mM / 32C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 32C/
#   [move]        single_frequency_summary.csv -> 32C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/32C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_32C_80kHz_0.1Hz_pH=1.707.csv -> 32C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_32C_80kHz_0.1Hz_pH=1.707.nox -> 32C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/32C/whole-spectrum
#
# == 16mM / 34C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 34C/
#   [move]        single_frequency_summary.csv -> 34C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/34C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_34C_80kHz_0.1Hz_pH=1.710.csv -> 34C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_34C_80kHz_0.1Hz_pH=1.710.nox -> 34C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/34C/whole-spectrum
#
# == 16mM / 36C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 36C/
#   [move]        single_frequency_summary.csv -> 36C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/36C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_36C_80kHz_0.1Hz_pH=1.711.csv -> 36C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_36C_80kHz_0.1Hz_pH=1.711.nox -> 36C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/36C/whole-spectrum
#
# == 16mM / 38C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 38C/
#   [move]        single_frequency_summary.csv -> 38C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/38C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_38C_80kHz_0.1Hz_pH=1.711.csv -> 38C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_38C_80kHz_0.1Hz_pH=1.711.nox -> 38C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/38C/whole-spectrum
#
# == 16mM / 40C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 40C/
#   [move]        single_frequency_summary.csv -> 40C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/40C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_40C_80kHz_0.1Hz_pH=1.712.csv -> 40C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_40C_80kHz_0.1Hz_pH=1.712.nox -> 40C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/40C/whole-spectrum
#
# == 16mM / 42C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 42C/
#   [move]        single_frequency_summary.csv -> 42C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/42C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_42C_80kHz_0.1Hz_pH=1.711.csv -> 42C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_42C_80kHz_0.1Hz_pH=1.711.nox -> 42C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/42C/whole-spectrum
#
# == 16mM / 44C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 44C/
#   [move]        single_frequency_summary.csv -> 44C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/44C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_44C_80kHz_0.1Hz_pH=1.712.csv -> 44C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_44C_80kHz_0.1Hz_pH=1.712.nox -> 44C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/44C/whole-spectrum
#
# == 16mM / 46C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 46C/
#   [move]        single_frequency_summary.csv -> 46C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/46C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_46C_80kHz_0.1Hz_pH=1.714.csv -> 46C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_46C_80kHz_0.1Hz_pH=1.714.nox -> 46C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/46C/whole-spectrum
#
# == 16mM / 48C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 48C/
#   [move]        single_frequency_summary.csv -> 48C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/48C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_48C_80kHz_0.1Hz_pH=1.716.csv -> 48C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_48C_80kHz_0.1Hz_pH=1.716.nox -> 48C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/48C/whole-spectrum
#
# == 16mM / 50C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 50C/
#   [move]        single_frequency_summary.csv -> 50C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/50C/single-frequency
#   [move]        EIS_whole_spectrum_16mM_H2SO4_50C_80kHz_0.1Hz_pH=1.719.csv -> 50C/
#   [move]        EIS_whole_spectrum_16mM_H2SO4_50C_80kHz_0.1Hz_pH=1.719.nox -> 50C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/16mM/50C/whole-spectrum
#
# == 17mM / 26C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 26C/
#   [move]        single_frequency_summary.csv -> 26C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/26C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_26C_90kHz_0.1Hz_pH=1.656.csv -> 26C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_26C_90kHz_0.1Hz_pH=1.656.nox -> 26C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/26C/whole-spectrum
#
# == 17mM / 28C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 28C/
#   [move]        single_frequency_summary.csv -> 28C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/28C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_28C_90kHz_0.1Hz_pH=1.659.csv -> 28C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_28C_90kHz_0.1Hz_pH=1.659.nox -> 28C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/28C/whole-spectrum
#
# == 17mM / 30C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 30C/
#   [move]        single_frequency_summary.csv -> 30C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/30C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_30C_90kHz_0.1Hz_pH=1.662.csv -> 30C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_30C_90kHz_0.1Hz_pH=1.662.nox -> 30C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/30C/whole-spectrum
#
# == 17mM / 32C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 32C/
#   [move]        single_frequency_summary.csv -> 32C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/32C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_32C_90kHz_0.1Hz_pH=1.662.csv -> 32C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_32C_90kHz_0.1Hz_pH=1.662.nox -> 32C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/32C/whole-spectrum
#
# == 17mM / 34C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 34C/
#   [move]        single_frequency_summary.csv -> 34C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/34C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_34C_90kHz_0.1Hz_pH=1.661.csv -> 34C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_34C_90kHz_0.1Hz_pH=1.661.nox -> 34C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/34C/whole-spectrum
#
# == 17mM / 36C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 36C/
#   [move]        single_frequency_summary.csv -> 36C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/36C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_36C_90kHz_0.1Hz_pH=1.666.csv -> 36C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_36C_90kHz_0.1Hz_pH=1.666.nox -> 36C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/36C/whole-spectrum
#
# == 17mM / 38C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 38C/
#   [move]        single_frequency_summary.csv -> 38C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/38C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_38C_90kHz_0.1Hz_pH=1.670.csv -> 38C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_38C_90kHz_0.1Hz_pH=1.670.nox -> 38C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/38C/whole-spectrum
#
# == 17mM / 40C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 40C/
#   [move]        single_frequency_summary.csv -> 40C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/40C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_40C_90kHz_0.1Hz_pH=1.675.csv -> 40C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_40C_90kHz_0.1Hz_pH=1.675.nox -> 40C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/40C/whole-spectrum
#
# == 17mM / 42C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 42C/
#   [move]        single_frequency_summary.csv -> 42C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/42C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_42C_90kHz_0.1Hz_pH=1.678.csv -> 42C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_42C_90kHz_0.1Hz_pH=1.678.nox -> 42C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/42C/whole-spectrum
#
# == 17mM / 44C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 44C/
#   [move]        single_frequency_summary.csv -> 44C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/44C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_44C_90kHz_0.1Hz_pH=1.682.csv -> 44C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_44C_90kHz_0.1Hz_pH=1.682.nox -> 44C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/44C/whole-spectrum
#
# == 17mM / 46C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 46C/
#   [move]        single_frequency_summary.csv -> 46C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/46C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_46C_90kHz_0.1Hz_pH=1.686.csv -> 46C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_46C_90kHz_0.1Hz_pH=1.686.nox -> 46C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/46C/whole-spectrum
#
# == 17mM / 48C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 48C/
#   [move]        single_frequency_summary.csv -> 48C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/48C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_48C_90kHz_0.1Hz_pH=1.689.csv -> 48C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_48C_90kHz_0.1Hz_pH=1.689.nox -> 48C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/48C/whole-spectrum
#
# == 17mM / 50C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 50C/
#   [move]        single_frequency_summary.csv -> 50C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/50C/single-frequency
#   [move]        EIS_whole_spectrum_17mM_H2SO4_50C_90kHz_0.1Hz_pH=1.694.csv -> 50C/
#   [move]        EIS_whole_spectrum_17mM_H2SO4_50C_90kHz_0.1Hz_pH=1.694.nox -> 50C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/17mM/50C/whole-spectrum
#
# == 18mM / 26C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 26C/
#   [move]        single_frequency_summary.csv -> 26C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/26C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_26C_90kHz_0.1Hz_pH=1.640.csv -> 26C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_26C_90kHz_0.1Hz_pH=1.640.nox -> 26C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/26C/whole-spectrum
#
# == 18mM / 28C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 28C/
#   [move]        single_frequency_summary.csv -> 28C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/28C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_28C_90kHz_0.1Hz_pH=1.641.csv -> 28C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_28C_90kHz_0.1Hz_pH=1.641.nox -> 28C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/28C/whole-spectrum
#
# == 18mM / 30C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 30C/
#   [move]        single_frequency_summary.csv -> 30C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/30C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_30C_90kHz_0.1Hz_pH=1.644.csv -> 30C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_30C_90kHz_0.1Hz_pH=1.644.nox -> 30C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/30C/whole-spectrum
#
# == 18mM / 32C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 32C/
#   [move]        single_frequency_summary.csv -> 32C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/32C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_32C_90kHz_0.1Hz_pH=1.650.csv -> 32C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_32C_90kHz_0.1Hz_pH=1.650.nox -> 32C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/32C/whole-spectrum
#
# == 18mM / 34C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 34C/
#   [move]        single_frequency_summary.csv -> 34C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/34C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_34C_90kHz_0.1Hz_pH=1.652.csv -> 34C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_34C_90kHz_0.1Hz_pH=1.652.nox -> 34C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/34C/whole-spectrum
#
# == 18mM / 36C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 36C/
#   [move]        single_frequency_summary.csv -> 36C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/36C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_36C_90kHz_0.1Hz_pH=1.656.csv -> 36C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_36C_90kHz_0.1Hz_pH=1.656.nox -> 36C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/36C/whole-spectrum
#
# == 18mM / 38C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 38C/
#   [move]        single_frequency_summary.csv -> 38C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/38C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_38C_90kHz_0.1Hz_pH=1.662.csv -> 38C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_38C_90kHz_0.1Hz_pH=1.662.nox -> 38C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/38C/whole-spectrum
#
# == 18mM / 40C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 40C/
#   [move]        single_frequency_summary.csv -> 40C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/40C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_40C_90kHz_0.1Hz_pH=1.665.csv -> 40C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_40C_90kHz_0.1Hz_pH=1.665.nox -> 40C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/40C/whole-spectrum
#
# == 18mM / 42C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 42C/
#   [move]        single_frequency_summary.csv -> 42C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/42C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_42C_90kHz_0.1Hz_pH=1.666.csv -> 42C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_42C_90kHz_0.1Hz_pH=1.666.nox -> 42C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/42C/whole-spectrum
#
# == 18mM / 44C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 44C/
#   [move]        single_frequency_summary.csv -> 44C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/44C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_44C_90kHz_0.1Hz_pH=1.672.csv -> 44C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_44C_90kHz_0.1Hz_pH=1.672.nox -> 44C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/44C/whole-spectrum
#
# == 18mM / 46C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 46C/
#   [move]        single_frequency_summary.csv -> 46C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/46C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_46C_90kHz_0.1Hz_pH=1.676.csv -> 46C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_46C_90kHz_0.1Hz_pH=1.676.nox -> 46C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/46C/whole-spectrum
#
# == 18mM / 48C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 48C/
#   [move]        single_frequency_summary.csv -> 48C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/48C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_48C_90kHz_0.1Hz_pH=1.680.csv -> 48C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_48C_90kHz_0.1Hz_pH=1.680.nox -> 48C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/48C/whole-spectrum
#
# == 18mM / 50C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 50C/
#   [move]        single_frequency_summary.csv -> 50C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/50C/single-frequency
#   [move]        EIS_whole_spectrum_18mM_H2SO4_50C_90kHz_0.1Hz_pH=1.683.csv -> 50C/
#   [move]        EIS_whole_spectrum_18mM_H2SO4_50C_90kHz_0.1Hz_pH=1.683.nox -> 50C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/18mM/50C/whole-spectrum
#
# == 19mM / 26C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 26C/
#   [move]        single_frequency_summary.csv -> 26C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/26C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_26C_100kHz_0.1Hz_pH=1.622.csv -> 26C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_26C_100kHz_0.1Hz_pH=1.622.nox -> 26C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/26C/whole-spectrum
#
# == 19mM / 28C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 28C/
#   [move]        single_frequency_summary.csv -> 28C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/28C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_28C_100kHz_0.1Hz_pH=1.625.csv -> 28C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_28C_100kHz_0.1Hz_pH=1.625.nox -> 28C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/28C/whole-spectrum
#
# == 19mM / 30C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 30C/
#   [move]        single_frequency_summary.csv -> 30C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/30C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_30C_100kHz_0.1Hz_pH=1.628.csv -> 30C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_30C_100kHz_0.1Hz_pH=1.628.nox -> 30C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/30C/whole-spectrum
#
# == 19mM / 32C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 32C/
#   [move]        single_frequency_summary.csv -> 32C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/32C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_32C_100kHz_0.1Hz_pH=1.628.csv -> 32C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_32C_100kHz_0.1Hz_pH=1.628.nox -> 32C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/32C/whole-spectrum
#
# == 19mM / 34C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 34C/
#   [move]        single_frequency_summary.csv -> 34C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/34C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_34C_100kHz_0.1Hz_pH=1.628.csv -> 34C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_34C_100kHz_0.1Hz_pH=1.628.nox -> 34C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/34C/whole-spectrum
#
# == 19mM / 36C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 36C/
#   [move]        single_frequency_summary.csv -> 36C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/36C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_36C_100kHz_0.1Hz_pH=1.632.csv -> 36C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_36C_100kHz_0.1Hz_pH=1.632.nox -> 36C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/36C/whole-spectrum
#
# == 19mM / 38C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 38C/
#   [move]        single_frequency_summary.csv -> 38C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/38C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_38C_100kHz_0.1Hz_pH=1.636.csv -> 38C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_38C_100kHz_0.1Hz_pH=1.636.nox -> 38C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/38C/whole-spectrum
#
# == 19mM / 40C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 40C/
#   [move]        single_frequency_summary.csv -> 40C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/40C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_40C_100kHz_0.1Hz_pH=1.640.csv -> 40C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_40C_100kHz_0.1Hz_pH=1.640.nox -> 40C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/40C/whole-spectrum
#
# == 19mM / 42C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 42C/
#   [move]        single_frequency_summary.csv -> 42C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/42C/single-frequency
#   [move]        EIS_whole_spectrum_19mM_H2SO4_42C_100kHz_0.1Hz_pH=1.645.csv -> 42C/
#   [move]        EIS_whole_spectrum_19mM_H2SO4_42C_100kHz_0.1Hz_pH=1.645.nox -> 42C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/19mM/42C/whole-spectrum
#
# == 19mM / 44C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 44C/
#   [move]        single_frequency_summary.csv -> 44C/
# ...
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/28C/whole-spectrum
#
# == 20mM / 30C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 30C/
#   [move]        single_frequency_summary.csv -> 30C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/30C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_30C_100kHz_0.1Hz_pH=1.610.csv -> 30C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_30C_100kHz_0.1Hz_pH=1.610.nox -> 30C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/30C/whole-spectrum
#
# == 20mM / 32C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 32C/
#   [move]        single_frequency_summary.csv -> 32C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/32C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_32C_100kHz_0.1Hz_pH=1.617.csv -> 32C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_32C_100kHz_0.1Hz_pH=1.617.nox -> 32C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/32C/whole-spectrum
#
# == 20mM / 34C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 34C/
#   [move]        single_frequency_summary.csv -> 34C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/34C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_34C_100kHz_0.1Hz_pH=1.617.csv -> 34C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_34C_100kHz_0.1Hz_pH=1.617.nox -> 34C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/34C/whole-spectrum
#
# == 20mM / 36C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 36C/
#   [move]        single_frequency_summary.csv -> 36C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/36C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_36C_100kHz_0.1Hz_pH=1.620.csv -> 36C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_36C_100kHz_0.1Hz_pH=1.620.nox -> 36C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/36C/whole-spectrum
#
# == 20mM / 38C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 38C/
#   [move]        single_frequency_summary.csv -> 38C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/38C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_38C_100kHz_0.1Hz_pH=1.624.csv -> 38C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_38C_100kHz_0.1Hz_pH=1.624.nox -> 38C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/38C/whole-spectrum
#
# == 20mM / 40C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 40C/
#   [move]        single_frequency_summary.csv -> 40C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/40C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_40C_100kHz_0.1Hz_pH=1.628.csv -> 40C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_40C_100kHz_0.1Hz_pH=1.628.nox -> 40C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/40C/whole-spectrum
#
# == 20mM / 42C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 42C/
#   [move]        single_frequency_summary.csv -> 42C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/42C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_42C_100kHz_0.1Hz_pH=1.631.csv -> 42C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_42C_100kHz_0.1Hz_pH=1.631.nox -> 42C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/42C/whole-spectrum
#
# == 20mM / 44C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 44C/
#   [move]        single_frequency_summary.csv -> 44C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/44C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_44C_100kHz_0.1Hz_pH=1.635.csv -> 44C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_44C_100kHz_0.1Hz_pH=1.635.nox -> 44C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/44C/whole-spectrum
#
# == 20mM / 46C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 46C/
#   [move]        single_frequency_summary.csv -> 46C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/46C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_46C_100kHz_0.1Hz_pH=1.639.csv -> 46C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_46C_100kHz_0.1Hz_pH=1.639.nox -> 46C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/46C/whole-spectrum
#
# == 20mM / 48C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 48C/
#   [move]        single_frequency_summary.csv -> 48C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/48C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_48C_100kHz_0.1Hz_pH=1.643.csv -> 48C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_48C_100kHz_0.1Hz_pH=1.643.nox -> 48C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/48C/whole-spectrum
#
# == 20mM / 50C ==
# [extract] single_frequency_summary.csv from single-frequency/ -> 50C/
#   [move]        single_frequency_summary.csv -> 50C/
# [delete] single-frequency -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/50C/single-frequency
#   [move]        EIS_whole_spectrum_20mM_H2SO4_50C_100kHz_0.1Hz_pH=1.648.csv -> 50C/
#   [move]        EIS_whole_spectrum_20mM_H2SO4_50C_100kHz_0.1Hz_pH=1.648.nox -> 50C/
# [delete] whole-spectrum -> /Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole/20mM/50C/whole-spectrum
#
# == 2mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 2mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 3mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 4mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 5mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 6mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 7mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 8mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 26C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 28C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 30C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 32C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 34C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 36C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 38C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 40C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 42C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 44C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 46C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 48C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# == 9mM / 50C ==
# [info]   single-frequency not found
# [info]   whole-spectrum not found
#
# --- SUMMARY ---
# Temperature folders seen        : 260
# Summaries extracted             : 91
# 'single-frequency' deleted      : 91
# Items moved from 'whole'        : 182
# 'whole-spectrum' deleted        : 91
# Dry-run: False | Conflict policy: rename
# {'single_deleted': 91,
#  'whole_moved': 182,
#  'whole_deleted': 91,
#  'temps_seen': 260,
#  'summaries_extracted': 91}

# %% [markdown]
# # This Block of code takes the EIS_whole_scpectrums with  "_3" in the end and deletes the other versions and in the end removes the "_3" from that file and save it.

# %%
from pathlib import Path
import re, shutil
from typing import Dict, List

# >>>>> SET YOUR ROOT FOLDER HERE <<<<<
ROOT_DIR = Path(r"/Volumes/01785304894/Uni Stuff/Measurement_Data/2025/June-July/NPG-500mM-H2SO4-whole")

# Options
CONCENTRATIONS = [f"{i}mM" for i in range(1, 14)]  # 1mM..13mM
ALLOWED_EXTS   = {".csv"}                          # only touch CSVs
CONFLICT       = "overwrite"                       # "overwrite" | "skip" | "rename"
DRY_RUN        = False                              # set to False to apply changes

# Match stems like "..._pH=2.61_3" (i.e., trailing _<digits> replicate)
# and ensure the name starts with "EIS_whole_spectrum" (case-insensitive)
def parse_replicate(stem: str):
    m = re.match(r'(?i)^(?P<prefix>EIS_whole_spectrum.*)_(?P<rep>\d+)$', stem)
    if not m:
        return None, None
    return m.group('prefix'), int(m.group('rep'))

def unique_target(path: Path) -> Path:
    if not path.exists(): return path
    base, ext = path.stem, path.suffix
    i = 1
    while True:
        cand = path.with_name(f"{base} (copy{'' if i==1 else f' {i}'}){ext}")
        if not cand.exists():
            return cand
        i += 1

def apply_changes(root: Path) -> None:
    if not root.is_dir():
        raise FileNotFoundError(f"Root not found: {root}")

    # Walk concentrations 1mM..13mM
    for conc_dir in sorted(p for p in root.iterdir() if p.is_dir() and p.name in CONCENTRATIONS):
        for temp_dir in sorted(p for p in conc_dir.iterdir() if p.is_dir()):
            print(f"\n== {conc_dir.name} / {temp_dir.name} ==")

            # Group files by base (prefix without _rep)
            groups: Dict[str, Dict[int, Path]] = {}
            for f in temp_dir.iterdir():
                if not f.is_file(): 
                    continue
                if ALLOWED_EXTS and f.suffix.lower() not in ALLOWED_EXTS:
                    continue
                base, rep = parse_replicate(f.stem)
                if base is None:
                    continue
                groups.setdefault(base, {})[rep] = f

            if not groups:
                print("  [info] No matching replicated files here.")
                continue

            # For each base set of replicates: keep _3, delete others, rename kept
            for base, reps in sorted(groups.items()):
                keep = reps.get(3)
                others = [p for r,p in reps.items() if r != 3]

                if keep is None:
                    # No _3 present → delete all replicates of this base
                    print(f"  [warn] No _3 file for: {base}. Deleting {len(others)} replicate(s).")
                    for p in others:
                        print(f"    [delete] {p.name}")
                        if not DRY_RUN:
                            p.unlink(missing_ok=True)
                    continue

                # Delete non-3 replicates
                for p in others:
                    print(f"  [delete] {p.name}")
                    if not DRY_RUN:
                        p.unlink(missing_ok=True)

                # Rename _3 → base (drop suffix)
                target = keep.with_name(f"{base}{keep.suffix}")
                if target == keep:
                    print(f"  [keep]    {keep.name} (already without suffix)")
                else:
                    if target.exists():
                        if CONFLICT == "skip":
                            print(f"  [skip]    rename {keep.name} -> {target.name} (target exists)")
                        elif CONFLICT == "overwrite":
                            print(f"  [overwrite] {target.name} then rename {keep.name}")
                            if not DRY_RUN:
                                target.unlink(missing_ok=True)
                                keep.rename(target)
                        elif CONFLICT == "rename":
                            new_target = unique_target(target)
                            print(f"  [rename]  {keep.name} -> {new_target.name}")
                            if not DRY_RUN:
                                keep.rename(new_target)
                        else:
                            raise ValueError("CONFLICT must be overwrite|skip|rename")
                    else:
                        print(f"  [rename]  {keep.name} -> {target.name}")
                        if not DRY_RUN:
                            keep.rename(target)

# Run (inspect output first; set DRY_RUN=False above to apply)
apply_changes(ROOT_DIR)
# Out:
# == 10mM / 26C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864_3.csv -> EIS_whole_spectrum_10mM_H2SO4_26C_60kHz_0.1Hz_pH=1.864.csv
#
# == 10mM / 28C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870_3.csv -> EIS_whole_spectrum_10mM_H2SO4_28C_60kHz_0.1Hz_pH=1.870.csv
#
# == 10mM / 30C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873_3.csv -> EIS_whole_spectrum_10mM_H2SO4_30C_60kHz_0.1Hz_pH=1.873.csv
#
# == 10mM / 32C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876_3.csv -> EIS_whole_spectrum_10mM_H2SO4_32C_60kHz_0.1Hz_pH=1.876.csv
#
# == 10mM / 34C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879_3.csv -> EIS_whole_spectrum_10mM_H2SO4_34C_60kHz_0.1Hz_pH=1.879.csv
#
# == 10mM / 36C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882_3.csv -> EIS_whole_spectrum_10mM_H2SO4_36C_60kHz_0.1Hz_pH=1.882.csv
#
# == 10mM / 38C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883_3.csv -> EIS_whole_spectrum_10mM_H2SO4_38C_60kHz_0.1Hz_pH=1.883.csv
#
# == 10mM / 40C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885_3.csv -> EIS_whole_spectrum_10mM_H2SO4_40C_60kHz_0.1Hz_pH=1.885.csv
#
# == 10mM / 42C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886_3.csv -> EIS_whole_spectrum_10mM_H2SO4_42C_60kHz_0.1Hz_pH=1.886.csv
#
# == 10mM / 44C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884_3.csv -> EIS_whole_spectrum_10mM_H2SO4_44C_60kHz_0.1Hz_pH=1.884.csv
#
# == 10mM / 46C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886_3.csv -> EIS_whole_spectrum_10mM_H2SO4_46C_60kHz_0.1Hz_pH=1.886.csv
#
# == 10mM / 48C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887_3.csv -> EIS_whole_spectrum_10mM_H2SO4_48C_60kHz_0.1Hz_pH=1.887.csv
#
# == 10mM / 50C ==
#   [delete] EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890_1.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890_2.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890_4.csv
#   [delete] EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890_5.csv
#   [rename]  EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890_3.csv -> EIS_whole_spectrum_10mM_H2SO4_50C_60kHz_0.1Hz_pH=1.890.csv
#
# == 11mM / 26C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818_3.csv -> EIS_whole_spectrum_11mM_H2SO4_26C_60kHz_0.1Hz_pH=1.818.csv
#
# == 11mM / 28C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820_3.csv -> EIS_whole_spectrum_11mM_H2SO4_28C_60kHz_0.1Hz_pH=1.820.csv
#
# == 11mM / 30C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822_3.csv -> EIS_whole_spectrum_11mM_H2SO4_30C_60kHz_0.1Hz_pH=1.822.csv
#
# == 11mM / 32C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824_3.csv -> EIS_whole_spectrum_11mM_H2SO4_32C_60kHz_0.1Hz_pH=1.824.csv
#
# == 11mM / 34C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829_3.csv -> EIS_whole_spectrum_11mM_H2SO4_34C_60kHz_0.1Hz_pH=1.829.csv
#
# == 11mM / 36C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830_3.csv -> EIS_whole_spectrum_11mM_H2SO4_36C_60kHz_0.1Hz_pH=1.830.csv
#
# == 11mM / 38C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836_3.csv -> EIS_whole_spectrum_11mM_H2SO4_38C_60kHz_0.1Hz_pH=1.836.csv
#
# == 11mM / 40C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837_3.csv -> EIS_whole_spectrum_11mM_H2SO4_40C_60kHz_0.1Hz_pH=1.837.csv
#
# == 11mM / 42C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840_3.csv -> EIS_whole_spectrum_11mM_H2SO4_42C_60kHz_0.1Hz_pH=1.840.csv
#
# == 11mM / 44C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842_3.csv -> EIS_whole_spectrum_11mM_H2SO4_44C_60kHz_0.1Hz_pH=1.842.csv
#
# == 11mM / 46C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844_3.csv -> EIS_whole_spectrum_11mM_H2SO4_46C_60kHz_0.1Hz_pH=1.844.csv
#
# == 11mM / 48C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848_3.csv -> EIS_whole_spectrum_11mM_H2SO4_48C_60kHz_0.1Hz_pH=1.848.csv
#
# == 11mM / 50C ==
#   [delete] EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852_1.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852_2.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852_4.csv
#   [delete] EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852_5.csv
#   [rename]  EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852_3.csv -> EIS_whole_spectrum_11mM_H2SO4_50C_60kHz_0.1Hz_pH=1.852.csv
#
# == 12mM / 26C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803_3.csv -> EIS_whole_spectrum_12mM_H2SO4_26C_60kHz_0.1Hz_pH=1.803.csv
#
# == 12mM / 28C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805_3.csv -> EIS_whole_spectrum_12mM_H2SO4_28C_60kHz_0.1Hz_pH=1.805.csv
#
# == 12mM / 30C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814_3.csv -> EIS_whole_spectrum_12mM_H2SO4_30C_60kHz_0.1Hz_pH=1.814.csv
#
# == 12mM / 32C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819_3.csv -> EIS_whole_spectrum_12mM_H2SO4_32C_60kHz_0.1Hz_pH=1.819.csv
#
# == 12mM / 34C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822_3.csv -> EIS_whole_spectrum_12mM_H2SO4_34C_60kHz_0.1Hz_pH=1.822.csv
#
# == 12mM / 36C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821_3.csv -> EIS_whole_spectrum_12mM_H2SO4_36C_60kHz_0.1Hz_pH=1.821.csv
#
# == 12mM / 38C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823_3.csv -> EIS_whole_spectrum_12mM_H2SO4_38C_60kHz_0.1Hz_pH=1.823.csv
#
# == 12mM / 40C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825_3.csv -> EIS_whole_spectrum_12mM_H2SO4_40C_60kHz_0.1Hz_pH=1.825.csv
#
# == 12mM / 42C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825_3.csv -> EIS_whole_spectrum_12mM_H2SO4_42C_60kHz_0.1Hz_pH=1.825.csv
#
# == 12mM / 44C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827_3.csv -> EIS_whole_spectrum_12mM_H2SO4_44C_60kHz_0.1Hz_pH=1.827.csv
#
# == 12mM / 46C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832_3.csv -> EIS_whole_spectrum_12mM_H2SO4_46C_60kHz_0.1Hz_pH=1.832.csv
#
# == 12mM / 48C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836_3.csv -> EIS_whole_spectrum_12mM_H2SO4_48C_60kHz_0.1Hz_pH=1.836.csv
#
# == 12mM / 50C ==
#   [delete] EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839_1.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839_2.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839_4.csv
#   [delete] EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839_5.csv
#   [rename]  EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839_3.csv -> EIS_whole_spectrum_12mM_H2SO4_50C_60kHz_0.1Hz_pH=1.839.csv
#
# == 13mM / 26C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762_3.csv -> EIS_whole_spectrum_13mM_H2SO4_26C_60kHz_0.1Hz_pH=1.762.csv
#
# == 13mM / 28C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765_3.csv -> EIS_whole_spectrum_13mM_H2SO4_28C_60kHz_0.1Hz_pH=1.765.csv
#
# == 13mM / 30C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769_3.csv -> EIS_whole_spectrum_13mM_H2SO4_30C_60kHz_0.1Hz_pH=1.769.csv
#
# == 13mM / 32C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771_3.csv -> EIS_whole_spectrum_13mM_H2SO4_32C_60kHz_0.1Hz_pH=1.771.csv
#
# == 13mM / 34C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772_3.csv -> EIS_whole_spectrum_13mM_H2SO4_34C_60kHz_0.1Hz_pH=1.772.csv
#
# == 13mM / 36C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776_3.csv -> EIS_whole_spectrum_13mM_H2SO4_36C_60kHz_0.1Hz_pH=1.776.csv
#
# == 13mM / 38C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780_3.csv -> EIS_whole_spectrum_13mM_H2SO4_38C_60kHz_0.1Hz_pH=1.780.csv
#
# == 13mM / 40C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783_3.csv -> EIS_whole_spectrum_13mM_H2SO4_40C_60kHz_0.1Hz_pH=1.783.csv
#
# == 13mM / 42C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785_3.csv -> EIS_whole_spectrum_13mM_H2SO4_42C_60kHz_0.1Hz_pH=1.785.csv
#
# == 13mM / 44C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789_3.csv -> EIS_whole_spectrum_13mM_H2SO4_44C_60kHz_0.1Hz_pH=1.789.csv
#
# == 13mM / 46C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793_3.csv -> EIS_whole_spectrum_13mM_H2SO4_46C_60kHz_0.1Hz_pH=1.793.csv
#
# == 13mM / 48C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797_3.csv -> EIS_whole_spectrum_13mM_H2SO4_48C_60kHz_0.1Hz_pH=1.797.csv
#
# == 13mM / 50C ==
#   [delete] EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800_1.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800_2.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800_4.csv
#   [delete] EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800_5.csv
#   [rename]  EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800_3.csv -> EIS_whole_spectrum_13mM_H2SO4_50C_60kHz_0.1Hz_pH=1.800.csv
#
# == 1mM / 26C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17_3.csv -> EIS_whole_spectrum_1mM_H2SO4_26C_10kHz_0.1Hz_pH=3.17.csv
#
# == 1mM / 28C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17_3.csv -> EIS_whole_spectrum_1mM_H2SO4_28C_10kHz_0.1Hz_pH=3.17.csv
#
# == 1mM / 30C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17_3.csv -> EIS_whole_spectrum_1mM_H2SO4_30C_10kHz_0.1Hz_pH=3.17.csv
#
# == 1mM / 32C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18_3.csv -> EIS_whole_spectrum_1mM_H2SO4_32C_10kHz_0.1Hz_pH=3.18.csv
#
# == 1mM / 34C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18_3.csv -> EIS_whole_spectrum_1mM_H2SO4_34C_10kHz_0.1Hz_pH=3.18.csv
#
# == 1mM / 36C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18_3.csv -> EIS_whole_spectrum_1mM_H2SO4_36C_10kHz_0.1Hz_pH=3.18.csv
#
# == 1mM / 38C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18_3.csv -> EIS_whole_spectrum_1mM_H2SO4_38C_10kHz_0.1Hz_pH=3.18.csv
#
# == 1mM / 40C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18_3.csv -> EIS_whole_spectrum_1mM_H2SO4_40C_10kHz_0.1Hz_pH=3.18.csv
#
# == 1mM / 42C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17_3.csv -> EIS_whole_spectrum_1mM_H2SO4_42C_10kHz_0.1Hz_pH=3.17.csv
#
# == 1mM / 44C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17_3.csv -> EIS_whole_spectrum_1mM_H2SO4_44C_10kHz_0.1Hz_pH=3.17.csv
#
# == 1mM / 46C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17_3.csv -> EIS_whole_spectrum_1mM_H2SO4_46C_10kHz_0.1Hz_pH=3.17.csv
#
# == 1mM / 48C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17_3.csv -> EIS_whole_spectrum_1mM_H2SO4_48C_10kHz_0.1Hz_pH=3.17.csv
#
# == 1mM / 50C ==
#   [delete] EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18_1.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18_2.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18_4.csv
#   [delete] EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18_5.csv
#   [rename]  EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18_3.csv -> EIS_whole_spectrum_1mM_H2SO4_50C_10kHz_0.1Hz_pH=3.18.csv
#
# == 2mM / 26C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61_3.csv -> EIS_whole_spectrum_2mM_H2SO4_26C_10kHz_0.1Hz_pH=2.61.csv
#
# == 2mM / 28C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61_3.csv -> EIS_whole_spectrum_2mM_H2SO4_28C_10kHz_0.1Hz_pH=2.61.csv
#
# == 2mM / 30C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_30C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 32C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_32C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 34C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_34C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 36C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_36C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 38C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_38C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 40C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_40C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 42C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_42C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 44C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_44C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 46C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_46C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 48C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_48C_10kHz_0.1Hz_pH=2.62.csv
#
# == 2mM / 50C ==
#   [delete] EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62_1.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62_2.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62_4.csv
#   [delete] EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62_5.csv
#   [rename]  EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62_3.csv -> EIS_whole_spectrum_2mM_H2SO4_50C_10kHz_0.1Hz_pH=2.62.csv
#
# == 3mM / 26C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41_3.csv -> EIS_whole_spectrum_3mM_H2SO4_26C_30kHz_0.1Hz_pH=2.41.csv
#
# == 3mM / 28C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42_3.csv -> EIS_whole_spectrum_3mM_H2SO4_28C_30kHz_0.1Hz_pH=2.42.csv
#
# == 3mM / 30C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42_3.csv -> EIS_whole_spectrum_3mM_H2SO4_30C_30kHz_0.1Hz_pH=2.42.csv
#
# == 3mM / 32C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_32C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 34C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_34C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 36C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_36C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 38C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_38C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 40C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_40C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 42C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_42C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 44C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_44C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 46C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_46C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 48C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_48C_30kHz_0.1Hz_pH=2.43.csv
#
# == 3mM / 50C ==
#   [delete] EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43_1.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43_2.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43_4.csv
#   [delete] EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43_5.csv
#   [rename]  EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43_3.csv -> EIS_whole_spectrum_3mM_H2SO4_50C_30kHz_0.1Hz_pH=2.43.csv
#
# == 4mM / 26C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26_3.csv -> EIS_whole_spectrum_4mM_H2SO4_26C_40kHz_0.1Hz_pH=2.26.csv
#
# == 4mM / 28C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27_3.csv -> EIS_whole_spectrum_4mM_H2SO4_28C_40kHz_0.1Hz_pH=2.27.csv
#
# == 4mM / 30C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27_3.csv -> EIS_whole_spectrum_4mM_H2SO4_30C_40kHz_0.1Hz_pH=2.27.csv
#
# == 4mM / 32C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27_3.csv -> EIS_whole_spectrum_4mM_H2SO4_32C_40kHz_0.1Hz_pH=2.27.csv
#
# == 4mM / 34C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_34C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 36C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_36C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 38C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_38C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 40C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_40C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 42C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_42C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 44C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_44C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 46C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_46C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 48C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_48C_40kHz_0.1Hz_pH=2.28.csv
#
# == 4mM / 50C ==
#   [delete] EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28_1.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28_2.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28_4.csv
#   [delete] EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28_5.csv
#   [rename]  EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28_3.csv -> EIS_whole_spectrum_4mM_H2SO4_50C_40kHz_0.1Hz_pH=2.28.csv
#
# == 5mM / 26C ==
#   [delete] EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168_1.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168_2.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168_4.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168_5.csv
#   [rename]  EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168_3.csv -> EIS_whole_spectrum_5mM_H2SO4_26C_40kHz_0.1Hz_pH=2.168.csv
#
# == 5mM / 28C ==
#   [delete] EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181_1.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181_2.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181_4.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181_5.csv
#   [rename]  EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181_3.csv -> EIS_whole_spectrum_5mM_H2SO4_28C_40kHz_0.1Hz_pH=2.181.csv
#
# == 5mM / 30C ==
#   [delete] EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186_1.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186_2.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186_4.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186_5.csv
#   [rename]  EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186_3.csv -> EIS_whole_spectrum_5mM_H2SO4_30C_40kHz_0.1Hz_pH=2.186.csv
#
# == 5mM / 32C ==
#   [delete] EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185_1.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185_2.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185_4.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185_5.csv
#   [rename]  EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185_3.csv -> EIS_whole_spectrum_5mM_H2SO4_32C_40kHz_0.1Hz_pH=2.185.csv
#
# == 5mM / 34C ==
#   [delete] EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188_1.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188_2.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188_4.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188_5.csv
#   [rename]  EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188_3.csv -> EIS_whole_spectrum_5mM_H2SO4_34C_40kHz_0.1Hz_pH=2.188.csv
#
# == 5mM / 36C ==
#   [delete] EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190_1.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190_2.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190_4.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190_5.csv
#   [rename]  EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190_3.csv -> EIS_whole_spectrum_5mM_H2SO4_36C_40kHz_0.1Hz_pH=2.190.csv
#
# == 5mM / 38C ==
#   [delete] EIS_whole_spectrum_5mM_H2SO4_38C_40kHz_0.1Hz_pH=2.190_1.csv
#   [delete] EIS_whole_spectrum_5mM_H2SO4_38C_40kHz_0.1Hz_pH=2.190_2.csv
# ...
#   [delete] EIS_whole_spectrum_7mM_H2SO4_30C_50kHz_0.1Hz_pH=2.025_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_30C_50kHz_0.1Hz_pH=2.025_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_30C_50kHz_0.1Hz_pH=2.025_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_30C_50kHz_0.1Hz_pH=2.025_3.csv -> EIS_whole_spectrum_7mM_H2SO4_30C_50kHz_0.1Hz_pH=2.025.csv
#
# == 7mM / 32C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028_3.csv -> EIS_whole_spectrum_7mM_H2SO4_32C_50kHz_0.1Hz_pH=2.028.csv
#
# == 7mM / 34C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030_3.csv -> EIS_whole_spectrum_7mM_H2SO4_34C_50kHz_0.1Hz_pH=2.030.csv
#
# == 7mM / 36C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031_3.csv -> EIS_whole_spectrum_7mM_H2SO4_36C_50kHz_0.1Hz_pH=2.031.csv
#
# == 7mM / 38C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034_3.csv -> EIS_whole_spectrum_7mM_H2SO4_38C_50kHz_0.1Hz_pH=2.034.csv
#
# == 7mM / 40C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034_3.csv -> EIS_whole_spectrum_7mM_H2SO4_40C_50kHz_0.1Hz_pH=2.034.csv
#
# == 7mM / 42C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035_3.csv -> EIS_whole_spectrum_7mM_H2SO4_42C_50kHz_0.1Hz_pH=2.035.csv
#
# == 7mM / 44C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033_3.csv -> EIS_whole_spectrum_7mM_H2SO4_44C_50kHz_0.1Hz_pH=2.033.csv
#
# == 7mM / 46C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034_3.csv -> EIS_whole_spectrum_7mM_H2SO4_46C_50kHz_0.1Hz_pH=2.034.csv
#
# == 7mM / 48C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034_3.csv -> EIS_whole_spectrum_7mM_H2SO4_48C_50kHz_0.1Hz_pH=2.034.csv
#
# == 7mM / 50C ==
#   [delete] EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035_1.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035_2.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035_4.csv
#   [delete] EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035_5.csv
#   [rename]  EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035_3.csv -> EIS_whole_spectrum_7mM_H2SO4_50C_50kHz_0.1Hz_pH=2.035.csv
#
# == 8mM / 26C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953_3.csv -> EIS_whole_spectrum_8mM_H2SO4_26C_50kHz_0.1Hz_pH=1.953.csv
#
# == 8mM / 28C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959_3.csv -> EIS_whole_spectrum_8mM_H2SO4_28C_50kHz_0.1Hz_pH=1.959.csv
#
# == 8mM / 30C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961_3.csv -> EIS_whole_spectrum_8mM_H2SO4_30C_50kHz_0.1Hz_pH=1.961.csv
#
# == 8mM / 32C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962_3.csv -> EIS_whole_spectrum_8mM_H2SO4_32C_50kHz_0.1Hz_pH=1.962.csv
#
# == 8mM / 34C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962_3.csv -> EIS_whole_spectrum_8mM_H2SO4_34C_50kHz_0.1Hz_pH=1.962.csv
#
# == 8mM / 36C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964_3.csv -> EIS_whole_spectrum_8mM_H2SO4_36C_50kHz_0.1Hz_pH=1.964.csv
#
# == 8mM / 38C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964_3.csv -> EIS_whole_spectrum_8mM_H2SO4_38C_50kHz_0.1Hz_pH=1.964.csv
#
# == 8mM / 40C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965_3.csv -> EIS_whole_spectrum_8mM_H2SO4_40C_50kHz_0.1Hz_pH=1.965.csv
#
# == 8mM / 42C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966_3.csv -> EIS_whole_spectrum_8mM_H2SO4_42C_50kHz_0.1Hz_pH=1.966.csv
#
# == 8mM / 44C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970_3.csv -> EIS_whole_spectrum_8mM_H2SO4_44C_50kHz_0.1Hz_pH=1.970.csv
#
# == 8mM / 46C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974_3.csv -> EIS_whole_spectrum_8mM_H2SO4_46C_50kHz_0.1Hz_pH=1.974.csv
#
# == 8mM / 48C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967_3.csv -> EIS_whole_spectrum_8mM_H2SO4_48C_50kHz_0.1Hz_pH=1.967.csv
#
# == 8mM / 50C ==
#   [delete] EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968_1.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968_2.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968_4.csv
#   [delete] EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968_5.csv
#   [rename]  EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968_3.csv -> EIS_whole_spectrum_8mM_H2SO4_50C_50kHz_0.1Hz_pH=1.968.csv
#
# == 9mM / 26C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895_3.csv -> EIS_whole_spectrum_9mM_H2SO4_26C_50kHz_0.1Hz_pH=1.895.csv
#
# == 9mM / 28C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903_3.csv -> EIS_whole_spectrum_9mM_H2SO4_28C_50kHz_0.1Hz_pH=1.903.csv
#
# == 9mM / 30C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905_3.csv -> EIS_whole_spectrum_9mM_H2SO4_30C_50kHz_0.1Hz_pH=1.905.csv
#
# == 9mM / 32C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907_3.csv -> EIS_whole_spectrum_9mM_H2SO4_32C_50kHz_0.1Hz_pH=1.907.csv
#
# == 9mM / 34C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906_3.csv -> EIS_whole_spectrum_9mM_H2SO4_34C_50kHz_0.1Hz_pH=1.906.csv
#
# == 9mM / 36C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908_3.csv -> EIS_whole_spectrum_9mM_H2SO4_36C_50kHz_0.1Hz_pH=1.908.csv
#
# == 9mM / 38C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912_3.csv -> EIS_whole_spectrum_9mM_H2SO4_38C_50kHz_0.1Hz_pH=1.912.csv
#
# == 9mM / 40C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915_3.csv -> EIS_whole_spectrum_9mM_H2SO4_40C_50kHz_0.1Hz_pH=1.915.csv
#
# == 9mM / 42C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917_3.csv -> EIS_whole_spectrum_9mM_H2SO4_42C_50kHz_0.1Hz_pH=1.917.csv
#
# == 9mM / 44C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919_3.csv -> EIS_whole_spectrum_9mM_H2SO4_44C_50kHz_0.1Hz_pH=1.919.csv
#
# == 9mM / 46C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920_3.csv -> EIS_whole_spectrum_9mM_H2SO4_46C_50kHz_0.1Hz_pH=1.920.csv
#
# == 9mM / 48C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924_3.csv -> EIS_whole_spectrum_9mM_H2SO4_48C_50kHz_0.1Hz_pH=1.924.csv
#
# == 9mM / 50C ==
#   [delete] EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927_1.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927_2.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927_4.csv
#   [delete] EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927_5.csv
#   [rename]  EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927_3.csv -> EIS_whole_spectrum_9mM_H2SO4_50C_50kHz_0.1Hz_pH=1.927.csv
